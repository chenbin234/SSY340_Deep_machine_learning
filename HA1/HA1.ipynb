# %% [markdown]
# ### Checklist for submission
#
# It is extremely important to make sure that:
#
# 1. Everything runs as expected (no bugs when running cells);
# 2. The output from each cell corresponds to its code (don't change any cell's contents without rerunning it afterwards);
# 3. All outputs are present (don't delete any of the outputs);
# 4. Fill in all the places that say `# YOUR CODE HERE`, or "**Your answer:** (fill in here)".
# 5. Never copy/paste any notebook cells. Inserting new cells is allowed, but it should not be necessary.
# 6. The notebook contains some hidden metadata which is important during our grading process. **Make sure not to corrupt any of this metadata!** The metadata may for example be corrupted if you copy/paste any notebook cells, or if you perform an unsuccessful git merge / git pull. It may also be pruned completely if using Google Colab, so watch out for this. Searching for "nbgrader" when opening the notebook in a text editor should take you to the important metadata entries.
# 7. Although we will try our very best to avoid this, it may happen that bugs are found after an assignment is released, and that we will push an updated version of the assignment to GitHub. If this happens, it is important that you update to the new version, while making sure the notebook metadata is properly updated as well. The safest way to make sure nothing gets messed up is to start from scratch on a clean updated version of the notebook, copy/pasting your code from the cells of the previous version into the cells of the new version.
# 8. If you need to have multiple parallel versions of this notebook, make sure not to move them to another directory.
# 9. Although not forced to work exclusively in the course `conda` environment, you need to make sure that the notebook will run in that environment, i.e. that you have not added any additional dependencies.
#
# **FOR HA1, HA2, HA3 ONLY:** Failing to meet any of these requirements might lead to either a subtraction of POEs (at best) or a request for resubmission (at worst).
#
# We advise you to perform the following steps before submission to ensure that requirements 1, 2, and 3 are always met: **Restart the kernel** (in the menubar, select Kernel$\rightarrow$Restart) and then **run all cells** (in the menubar, select Cell$\rightarrow$Run All). This might require a bit of time, so plan ahead for this (and possibly use a cloud GPU in HA1 and HA2 for this step). Finally press the "Save and Checkout" button before handing in, to make sure that all your changes are saved to this .ipynb file.

# %% [markdown]
# ### Fill in name of notebook file
# This might seem silly, but the version check below needs to know the filename of the current notebook, which is not trivial to find out programmatically.
#
# You might want to have several parallel versions of the notebook, and it is fine to rename the notebook as long as it stays in the same directory. **However**, if you do rename it, you also need to update its own filename below:

# %%
nb_fname = "HA1.ipynb"

# %% [markdown]
# ### Fill in group number and member names (use NAME2 and GROUP only for HA1, HA2 and HA3):

# %%
NAME1 = "Bingcheng Chen" 
NAME2 = "Matthieu Michel René Larnouhet"
GROUP = "HA Group 27"

# %% [markdown]
# ### Check Python version

# %%
from platform import python_version_tuple
assert python_version_tuple()[:2] == ('3','9'), "You are not running Python 3.9. Make sure to run Python through the course Conda environment."

# %% [markdown]
# ### Check that notebook server has access to all required resources, and that notebook has not moved

# %%
import os
nb_dirname = os.path.abspath('')
assignment_name = os.path.basename(nb_dirname)
assert assignment_name in ['IHA1', 'IHA2', 'HA1', 'HA2', 'HA3'], \
    '[ERROR] The notebook appears to have been moved from its original directory'

# %% [markdown]
# ### Verify correct nb_fname

# %%
from IPython.display import display, HTML
try:
    display(HTML(r'<script>if("{nb_fname}" != IPython.notebook.notebook_name) {{ alert("You have filled in nb_fname = \"{nb_fname}\", but this does not seem to match the notebook filename \"" + IPython.notebook.notebook_name + "\"."); }}</script>'.format(nb_fname=nb_fname)))
except NameError:
    assert False, 'Make sure to fill in the nb_fname variable above!'
# Out:
# <script>if("HA1.ipynb" != IPython.notebook.notebook_name) { alert("You have filled in nb_fname = \"HA1.ipynb\", but this does not seem to match the notebook filename \"" + IPython.notebook.notebook_name + "\"."); }</script>

# %% [markdown]
# ### Verify that your notebook is up-to-date and not corrupted in any way

# %%
import sys
sys.path.append('..')
from ha_utils import check_notebook_uptodate_and_not_corrupted
check_notebook_uptodate_and_not_corrupted(nb_dirname, nb_fname)
# Out:
# Matching current notebook against the following URL:
# http://raw.githubusercontent.com/dml-cth/deep-machine-learning/master/home-assignments/HA1/HA1.ipynb
# [SUCCESS] No major notebook mismatch found when comparing to latest GitHub version. (There might be minor updates, but even that is the case, submitting your work based on this notebook version would be acceptable.)

# %% [markdown]
# # HA1 - Cats and dogs

# %% [markdown]
# <img src="https://cdn.pixabay.com/photo/2015/05/20/10/03/cat-and-dog-775116_960_720.jpg" alt="Image of cats and dogs" style="width: 500px;"/>

# %% [markdown]
# For this home assignment, we'll use the Kaggle dataset for the [Dogs vs. Cats competition](https://www.kaggle.com/c/dogs-vs-cats). It is comprised of 25k colour images of dogs and cats. Our goal with this assignment will be to create a classifier that can discriminate between cats or dogs.
#
# The goal is to make sure that you all can independently create, train and evaluate a model using a popular deep learning framework. A secondary goal is also to expose you to GPU computing, either your own or via a cloud computing service. The focus is on implementing the models, and much of the surrounding code is provided for you. You are expected to understand the provided code.

# %% [markdown]
# ## Using your cloud GPU
#
# ### Strong recommendation:
# In order to make the most out of your GPU hours, first try solving the initial part of this notebook (tasks 0-3) in your own computer (these tasks can be solved on the CPU), and leave most of the available hours for solving tasks 4-5, and refining your best model further (and, if you have the spare hours, experiment a bit! (Task 6)).
#
# There may well be difficult to access a cloud GPU, we therefore suggest that you start working with the cloud parts as soon as possible. You do not need to complete tasks 2-3 before you start with the GPU requiring tasks (tasks 4-6). A suggested workflow is to complete the task 0-1, start with task 2 and then work on task 2-3 and 4-6 in parallell.
#
# ### Working efficiently:
# Training for several epochs just to have your code break at the last validation step is incredibly frustrating and inefficient. Good practice is to first test long training runs with a much simpler dry-run: a single epoch, a few batches et c.

# %% [markdown]
# Requirements:
# - Whenever we ask you to plot anything, be sure to add a title and label the axes. If you're plotting more than one curve in the same plot, also add a legend.
# - When we ask you to train an architecture, train it for a reasonable number of epochs. "Reasonable" here means you should be fairly confident that training for a higher number of epochs wouldn't impact your conclusions regarding the model's performance. When experimenting, a single epoch is often enough to tell whether your model setup has improved or not.
#
#
# Hints:
# - If you get errors saying you've exhausted the GPU resources, well, then you've exhausted the GPU resources. However, sometimes that's because Pytorch didn't release a part of the GPU's memory. If you think your CNN should fit in your memory during training, try restarting the kernel and directly training only that architecture.
# - Every group has enough cloud credits to complete this assignment. However, this statement assumes you'll use your resources judiciously (e.g. always try the code first in your machine and make sure everything works properly before starting your instances) and **won't forget to stop your instance after using it,**  otherwise you might run out of credits.
# - Before starting, take a look at the images we'll be using. This is a hard task, don't get discouraged if your first models perform poorly (several participants in the original competition didn't achieve an accuracy higher than 60%).
# - Solving the computer labs and individual home assignments is a good way to get prepared for this assignment.

# %% [markdown]
# ---
# ## 0. Imports
#
# In the following cell, add all the imports you'll use in this assignment.

# %%
# YOUR CODE HERE
from pathlib import Path
import matplotlib.pyplot as plt
import torch
from torchvision.transforms import Compose, ToTensor, Resize, InterpolationMode, Normalize
from torch import nn
import numpy as np
from torch.utils.data import DataLoader
import pandas as pd

# %% [markdown]
# ---
# ## 1. Loading the data and preprocessing
#
# In this part we will set up the data used in this assignment. You need to download it, then we'll walk you through how to make a custom Pytorch dataset abstraction. The abstraction enables you to visualise and play around with the image data and to finally create data loaders, which are necessary for the training.

# %% [markdown]
# The first step is to head to the [Kaggle website for the cats and dogs competition](https://www.kaggle.com/c/dogs-vs-cats/data) and download the data from there. You should download both the test and train folders together in one zip file (there is a `Download all` button at the bottom of the page). Unfortunately, you need to create a Kaggle account for this.
#
# **Only necessary for tasks 4-6**: Downloading the data to your local computer is quite straight-forward. Sooner or later you will have to upload the data to the cloud instance and that is a bit more tricky. There are a few ways to do it:
#
#  - Jupyter Notebook upload function. When starting the notebook server with the command `jupyter notebook` you are directed to a main page. In the top right corner there is an upload button.
#  - Using [`scp`](https://linuxize.com/post/how-to-use-scp-command-to-securely-transfer-files/) to copy files via an ssh connection.
#  - Using the [Kaggle CLI](https://github.com/Kaggle/kaggle-api). We have added it to the conda environment.
#
# To begin with, download the data to your local computer and create a folder structure that resembles the following (obviously, the folder names are up to you):
#
#
#          small_train             small_val                train                   val
#               |                      |                      |                      |
#               |                      |                      |                      |
#         -------------          -------------          -------------          -------------
#         |           |          |           |          |           |          |           |
#         |           |          |           |          |           |          |           |
#       cats        dogs       cats        dogs       cats        dogs       cats        dogs
#
#
# The `small_train` and `small_val` folders have the training and validation samples for your smaller subset of the data, while the `train` and `val` folders contain all the samples you extracted from Kaggle's `train.zip`.
# This is just a convenient way of having a smaller dataset to play with for faster prototyping.
#
# We provide you a notebook that shows how to achieve this folder structure (`create_project_notebook_structure.ipynb`), starting from the original `dogs-vs-cats.zip` file that you download from Kaggle. If you do use that notebook, we encourage you to understand how each step is being done, so you can generalize this knowledge to new datasets you'll encounter.

# %% [markdown]
# **(2 points)**
#
# For the smaller dataset, we advise you to use 70% of the data as training data (and thereby the remaining 30% for validation data). However, for the larger dataset, you should decide how to split between training and validation.
#
# **What percentage of the larger dataset did you decide to use for training?**
#
# **Did you decide to keep the same ratio split between train and validation sets for the larger dataset? Motivate your decision!**

# %% [markdown]
# **Your answer:** Validation dataset is used to see which of the many different models performs best (in order to select the best model), for larger dataset, usually 30% of the data for validation is not needed, in this case, we use 92% of the dataset for training, and 8% for validation.

# %% [markdown]
# Fill in the dataset paths (to be used later by your data loaders):

# %%
# TODO: Change the directories accordingly
train_path = "./train"
val_path = "./val"
small_train_path = "./small_train"
small_val_path = "./small_val"
# YOUR CODE HERE

# %% [markdown]
# ### 1.1 Dataset
#
# To create data loaders we first need to create a dataset abstraction class. The purpose of a data loader is to efficiently provide the CPU/GPU with mini-batches of data. We now work with data complex enough to actually warrant the use of data loaders. In particular, we don't want to load all images into memory at once.
#
# Like before, the data loader is an instance of the Pytorch [`DataLoader`](https://pytorch.org/docs/stable/data.html?highlight=dataloader#torch.utils.data.DataLoader) which wraps a class that inherits from [`Dataset`](https://pytorch.org/docs/stable/data.html#torch.utils.data.Dataset), that we create ourselves.
# Image classification is such a common task that Pytorch provides a ready-to-use dataset class for this task, called [`ImageFolder`](https://pytorch.org/vision/stable/datasets.html?highlight=imagefolder#imagefolder).
# Using this class however, is rather opaque so for your understanding we will show you how to construct a custom dataset class. If you know this method, you will be able to create a data loader for any dataset you may encounter.
#
# We construct a class `DogsCatsData` as a subclass of `Dataset`.
# The dataset subclass holds the actual data, or at least provides access to it.
# To make it work with the `DataLoader` class we need to implement two methods:
#
# - `__getitem__(self, index)`: return the `index`'th sample, i.e. a single pair of (image, label)
# - `__len__(self)`: simply return the total number of samples $N$ in the dataset.
#
# These methods are so called Python "magic" methods, signified by the leading and closing double underscores.
# They typically enable special syntax for a class: `__getitem__` enables indexing of a class, and `__len__` enables calling the `len` function:
# ```python
# # Consider an instance `data` of a class `MyDataset` implementing `__getitem__` and `__len__`
# data[10] # returns the item with index 10 in `data`
# len(data) # returns the length/size of `data`
# ```
# We will return to why these are needed in the `DataLoader` wrapping class
#
# Now, to the actual implementation: The idea is to have the dataset class only store the filenames of the images (and the corresponding label), not the images themselves. We will find and store the filenames in the constructor. The `__getitem__` method will use the index to look up the correct filename and load it into memory.
# The `__len__` method is left for you to implement.
#
# Being able to use and understand code you have not written is an important ability. Below you are required to interact with the dataset class with a simple completion of the implementation and by extracting some data from the class. This is partly to ensure that you understand this specific class and partly to show you some tools for exploring new code.

# %%
from torch.utils.data import Dataset
from itertools import chain
from PIL import Image

class DogsCatsData(Dataset):
    
    def __init__(self, root, transform, dog_label=1, cat_label=0):
        """Constructor
        
        Args:
            root (Path/str): Filepath to the data root, e.g. './small_train'
            transform (Compose): A composition of image transforms, see below.
        """
        
        root = Path(root)
        if not (root.exists() and root.is_dir()):
            raise ValueError(f"Data root '{root}' is invalid")
            
        self.root = root
        self.transform = transform
        self._dog_label = dog_label
        self._cat_label = cat_label
        
        # Collect samples, both cat and dog and store pairs of (filepath, label) in a simple list.
        self._samples = self._collect_samples()
            
    def __getitem__(self, index):
        """Get sample by index
        
        Args:
            index (int)
        
        Returns:
             The index'th sample (Tensor, int)
        """
        # Access the stored path and label for the correct index
        path, label = self._samples[index]
        # Load the image into memory
        img = Image.open(path)
        # Perform transforms, if any.
        if self.transform is not None:
            img = self.transform(img)
        return img, label
    
    def __len__(self):
        """Total number of samples"""
        # YOUR CODE HERE
        return len(self._samples)
    
    def _collect_samples(self):
        """Collect all paths and labels
        
        Helper method for the constructor
        """
        # Iterator over dog filpath
        dog_paths = self._collect_imgs_sub_dir(self.root / "dogs")
        # Iterator of pairs (path, dog label)
        # Again, we use the `map` function to create an iterator. It's use is not as common as the so called
        # 'list comprehension' you've previously seen, but a good alternative to have seen.
        dog_paths_and_labels = map(lambda path: (path, self._dog_label), dog_paths)
        # Same for cats
        cat_paths = self._collect_imgs_sub_dir(self.root / "cats")
        cat_paths_and_labels = map(lambda path: (path, self._cat_label), cat_paths)
        # Sorting is not strictly necessary, but filesystem globbing (wildcard search) is not deterministic,
        # and consistency is nice when debugging.
        return sorted(list(chain(dog_paths_and_labels, cat_paths_and_labels)), key=lambda x: x[0].stem)
     
    @staticmethod
    def _collect_imgs_sub_dir(sub_dir: Path):
        """Collect image paths in a directory
        
        Helper method for the constructor
        """
        if not sub_dir.exists():
            raise ValueError(f"Data root '{self.root}' must contain sub dir '{sub_dir.name}'")
        return sub_dir.glob("*.jpg")
    
    def get_sample_by_id(self, id_):
        """Get sample by image id
        
        Convenience method for exploration.
        The indices does not correspond to the image id's in the filenames.
        Here is a (rather inefficient) way of inspecting a specific image.
        
        Args:
            id_ (str): Image id, e.g. `dog.321`
        """
        id_index = [path.stem for (path, _) in self._samples].index(id_)
        return self[id_index]

# %% [markdown]
# **(2 points)**
#
# Show that you understand the implementation by creating an instance called `example_dataset` of it. Create it from the small training set.
# Use the instance to
#  1. Print the number of samples in it
#  2. Print the label of the second sample, note that this is a number (0 or 1)

# %%
# The Dataset constructor has a transform attribute, we will cover it below. Just use this for now:
# from torchvision.transforms import ToTensor, Compose
transform = Compose([ToTensor()])
# YOUR CODE HERE

example_dataset = DogsCatsData(small_train_path, transform=transform)

print(f'The number of samples in small_train is: {len(example_dataset)}')
print(f'The label of the second sample in small_train is: {example_dataset[1][1]}')
# Out:
# The number of samples in small_train is: 3500
# The label of the second sample in small_train is: 0

# %% [markdown]
# It is vital to explore your data, but it can be tricky to deal with images in the tensor format.
# To aid you, use the below helper function to visually inspect your images.

# %%
def display_image(axis, image_tensor):
    """Display a tensor as an image
    
    Args:
        axis (pyplot axis)
        image_tensor (torch.Tensor): tensor with shape (num_channels=3, width, heigth)
    """
    
    # See hint above
    if not isinstance(image_tensor, torch.Tensor):
        raise TypeError("The `display_image` function expects a `torch.Tensor` " +
                        "use the `ToTensor` transformation to convert the images to tensors.")
        
    # The imshow commands expects a `numpy array` with shape (3, width, height)
    # We rearrange the dimensions with `permute` and then convert it to `numpy`
    image_data = image_tensor.permute(1, 2, 0).numpy()
    height, width, _ = image_data.shape
    axis.imshow(image_data)
    axis.set_xlim(0, width)
    # By convention when working with images, the origin is at the top left corner.
    # Therefore, we switch the order of the y limits.
    axis.set_ylim(height, 0)

# Example usage
_, axis = plt.subplots()
some_random_index = 453
# Here we use the __getitem__ method as a "magic" method.
# Implementing it for a class, enables square bracket '[]' indexing
image_tensor, label = example_dataset[some_random_index]
display_image(axis, image_tensor)

# %% [markdown]
# ### 1.2 Preprocessing
# The `DogsCatsData` class constructor has an argument called `transform`. It allows us to transform or preprocess all the images in a batch, from the raw image data to a more suitable format. There are multiple motivations for preprocessing:
#
# - Some transformations might be needed to actually make the data work with our network (reshaping, permuting dimensions et c.).
# - Make the training more efficient by making the input dimensions smaller, e.g. resizing, cropping.
# - Artificially expanding the training data through [data augmentation](https://cartesianfaith.com/2016/10/06/what-you-need-to-know-about-data-augmentation-for-machine-learning/)
# - We have some clever idea of how to change the data to create a simpler optimisation problem.
#
# We do not expect you to do data augmentation, but feel free to preprocess the data as you see fit. Use the [documentation](https://pytorch.org/vision/stable/transforms.html#torchvision-transforms) to view available transforms. Extra important is the `Compose` transformation, which is a meta-transformation which composes actual ones, and the `ToTensor` transformation which is the simplest way to go from image to tensor format.
#
#
# Hints:
# - Revisit the `DogsCatsData` example usage to see how to use the `Compose` and `ToTensor` transformations.
# - When feeding the images to your CNN, you'll probably want all of them to have the same spatial size, even though the .jpeg files differ in this. Resizing the images can be done using the previously mentioned Pytorch Transforms.
# - Resizing the images to a smaller size while loading them can be beneficial as it speeds up training. The CNN's do surprisingly well on 64x64 or even 32x32 images. Shorter training cycles give you more time to experiment! Note: The VGG network used later in this assignment is specialised for images that are 224x224.
#
# We encourage you to explore the data and choose transformations that you believe to be useful. For exploration we provide you with a helper function to visually compare transformations side by side:

# %%
def compare_transforms(transformations, index):
    """Visually compare transformations side by side.
    Takes a list of DogsCatsData datasets with different compositions of transformations.
    It then display the `index`th image of the dataset for each transformed dataset in the list.
    
    Example usage:
        compare_transforms([dataset_with_transform_1, dataset_with_transform_2], 0)
    
    Args:
        transformations (list(DogsCatsData)): list of dataset instances with different transformations
        index (int): Index of the sample in the dataset you wish to compare.
    """
    
    # Here we combine two functions from basic python to validate the input to the function:
    # - `all` takes an iterable (something we can loop over, e.g. a list) of booleans
    #    and returns True if every element is True, otherwise it returns False.
    # - `isinstance` checks whether a variable is an instance of a particular type (class)
    if not all(isinstance(transf, Dataset) for transf in transformations):
        raise TypeError("All elements in the `transformations` list need to be of type Dataset")
        
    num_transformations = len(transformations)
    fig, axes = plt.subplots(1, num_transformations)
    
    # This is just a hack to make sure that `axes` is a list of the same length as `transformations`.
    # If we only have one element in the list, `plt.subplots` will not create a list of a single axis
    # but rather just an axis without a list.
    if num_transformations == 1:
        axes = [axes]
        
    for counter, (axis, transf) in enumerate(zip(axes, transformations)):
        axis.set_title(f"transf: {counter}")
        image_tensor = transf[index][0]
        display_image(axis, image_tensor)

    plt.show()

# %%
# Explore your dataset in this cell, you do not need to produce any results.
# YOUR CODE HERE
target_size=(64, 64)

# Resize the image
transform1 = Compose([
                    ToTensor(), 
                    Resize(target_size, interpolation=InterpolationMode.BILINEAR),
                      ])
example_dataset1 = DogsCatsData(small_train_path, transform1)

# Resize and normalize the image, target_size=(64, 64)
transform2 = Compose([
                    ToTensor(), 
                    Resize(target_size, interpolation=InterpolationMode.BILINEAR),
                    Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
                      ])
example_dataset2 = DogsCatsData(small_train_path, transform2)

# Resize and normalize the image, target_size=(32, 32)
transform3 = Compose([
                    ToTensor(), 
                    Resize(((224,224)), interpolation=InterpolationMode.BILINEAR),
                    Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
                      ])
example_dataset3 = DogsCatsData(small_train_path, transform3)


# print(len(example_dataset1))
# plot the difference of the three transform
compare_transforms([example_dataset, example_dataset1, example_dataset2, example_dataset3], 5)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# **(2 points)**
#
# Normalisation of the training data is popular in pre-processing. What is the argument or intuition for why this is a beneficial transformation?

# %% [markdown]
# **Your answer:**
# 1. Normalization can speed up the learning algorithms.
# 2. Without normalization, features with larger scales may dominate the learning process and result in slower convergence or finding a nonoptimal solution.
# 3. Normalization makes the model to focus more on the relative importance of features rather than their absolute values.

# %% [markdown]
# ### 1.3 Data loaders
# With our dataset class implementation in place, creating a `DataLoader` instance is simple.
#
# The data loader class wraps the dataset and provides a way to iterate over batches in the training loop.
# To produce batches, it gets the total number of samples $N$ with the dataset's `__len__` method.
# It divides the indices $1, \dots, N$ into equally sized index batches with $B$ (batch size) elements. A particular batch with pairs of image and label is created by calling the dataset's `__getitem__` method with the indices in the batch. NB: the last batch in an epoch might be smaller if $N$ is not divisible by $B$.
#
# Create the data loaders needed for training (use the small version of the data), in the cell below.
# The `DataLoader` class is documented [here](https://pytorch.org/docs/stable/data.html#torch.utils.data.DataLoader) , but it's not that much to it.
# You simply create a data loader with a dataset instance and some other (self-explanatory) settings:
#
# ```python
# train_dataloader = DataLoader(example_dataset, batch_size=batch_size, shuffle=True)
# ```
#
# **(1 point)**
#
# Create data loaders required for training and validation.
#
# Hints:
# - The specified `batch_size` should be chosen so that you train fast but don't run out of memory. You need to figure this out empirically; start small and increase the batch size until you run out of memory. Beyond this pragmatic approach, feel free to contribute to the highly contested scientific debate about the relation between batch size and generalisation.
# - The `DataLoader` constructor takes an optional argument `num_workers`, which defaults to `0` if not provided. Setting a higher number creates multiple threads which load batches concurrently. This can speed up training considerably.

# %%
# YOUR CODE HERE
small_train_dataset = DogsCatsData(small_train_path, transform2)
small_val_dataset = DogsCatsData(small_val_path, transform2)

small_train_dataloader = DataLoader(small_train_dataset, batch_size=64, shuffle=True)
small_val_dataloader = DataLoader(small_val_dataset, batch_size=64)

# %% [markdown]
# ---
# ## 2. Training
#
# ### 2.1 The first model
#
# **(3 points)**
#
# Now, it's time to create a model called `FirstCnn`. To begin with, you have to create a CNN to an exact specification. After that, you will get the chance to be more creative.
#
# For the first model, create a network that:
# - Inherits from [`nn.Module`](https://pytorch.org/docs/stable/generated/torch.nn.Module.html#torch.nn.Module)
# - Implements a constructor `__init__(self, img_size)`, a `forward(self, input_batch)` method and whatever other helper methods you deem necessary. Note that a (square) image size should be a parameter in the model's constructor. While not strictly necessary, it is an acceptable way of handling varying input dim's and it is convenient for testing.
# - Can handle square images of arbitrary size and arbitrary large mini-batch sizes (within memory limits, of course). You may assume that there are always three colour channels, i.e., a mini-batch will have the shape `(batch size = B, num channels = 3, img size = D, D)`
# - Has layers:
#     1. Two convolutional layers, each with 10 filters, kernel size = 3, stride = 1, padding = 0
#     2. A single fully connected layer.
# - Related layers such as a pooling operation are optional.
# - Choose suitable activation functions
# - Outputs the probability of the image belonging to the class 'dog'. Technically the output should consist of `B` probabilities, one for each image in the mini-batch and so have the shape `(B,)`.
#
# Hints:
#
# - The subpage for [`torch.nn`](https://pytorch.org/docs/stable/nn.html) is a good place to find the layer specifics.
# - Going from the last CNN layer to the final fully connected layer is not trivial. The convolutions produces feature maps which we can think of as an image with many channels, while the fully connected layer expects a row vector as input. Calculate how many output neurons the convolutions produce and use `.reshape` to make your tensor fit the fully connected layer. It is also common to see the `.view` and `.squeeze` methods to do the same thing. They basically do the same thing (apart from some differences in internal memory management) but are less transparent. *Hint within the hint:* remember that the fully connected layers expects a *batch* of 1D tensors.

# %%
# YOUR CODE HERE
import torch.nn.functional as F

class FirstCnn(nn.Module):
    def __init__(self, img_size):
        super().__init__()
        self.img_size = img_size
        self.conv1 = nn.Conv2d(in_channels=3, out_channels=10, kernel_size=3, stride=1, padding=0)
        self.conv2 = nn.Conv2d(in_channels=10,out_channels=10, kernel_size=3, stride=1, padding=0)
        self.fc1 = nn.Linear(self._output_size(), 1)
        self.sigmoid = nn.Sigmoid()

    def forward(self, input_batch):
        x = F.relu(self.conv1(input_batch))
        x = F.max_pool2d(x, kernel_size=2)
        x = F.relu(self.conv2(x))
        x = x.view(-1, self._output_size())
        # x = self.fc1(x)
        x = self.sigmoid(self.fc1(x))

        return x.squeeze()

    def _output_size(self):
        # calculate the output size after 2 convolutional layer and 1 pooling layer
        conv1_W_H = (self.img_size - 3 + 2 * 0) / 1 + 1
        maxpool_W_H = (conv1_W_H - 2) / 2 + 1
        conv2_W_H = (maxpool_W_H - 3 + 2 * 0) / 1 + 1
        return int(conv2_W_H * conv2_W_H * 10)


img_size = 64
batch_size = 64

model = FirstCnn(img_size)  
print(model)
# Out:
# FirstCnn(
#   (conv1): Conv2d(3, 10, kernel_size=(3, 3), stride=(1, 1))
#   (conv2): Conv2d(10, 10, kernel_size=(3, 3), stride=(1, 1))
#   (fc1): Linear(in_features=8410, out_features=1, bias=True)
#   (sigmoid): Sigmoid()
# )

# %%
def test_model(model_class):
    assert issubclass(model_class, nn.Module), "Model class should inherit from nn.Module"
    
    assert getattr(model_class, "forward", None) is not None, "Model class should have a 'forward' method"
    
    _test_output(model_class, some_img_size=224, some_batch_size=64)
    _test_output(model_class, some_img_size=32, some_batch_size=8)
    
    print("Test passed.")

def _test_output(model_class, some_img_size, some_batch_size):
    random_input = torch.rand(some_batch_size, 3, some_img_size, some_img_size)
    model_instance = model_class(img_size=some_img_size)
    output = model_instance.forward(random_input)
    output_shape = list(output.shape)
    assert output_shape == [some_batch_size], f"Expected output size [{some_batch_size}], got {output_shape}"
    
# Note that the test takes the actual class, not an instance of it, as input.
# Here, we assume that the model class is named 'FirstCnn'
test_model(FirstCnn)
# Out:
# Test passed.

# %% [markdown]
# **(3 points)**
#
# You have been told that one of the benefits of CNN is that it can handle input of different sizes. Yet, you needed to know the image size in the constructor.
# Explain how you made your model handle different input sizes and why it is necessary, despite it being a CNN.

# %% [markdown]
# **Your answer:**
#
# **How to make CNN model handle different input size**
# 1. we can preprocess input image by resizing them to a fix size.
# 2. we can also using adaptive pooling layers (AdaptiveMaxPool2d) to adapt the different size of input images.
#
# **Why it is necessary**
#
# Generally, CNN ends with few fully connected layers. The number of input neurons to the first FC layers depends on the dimensions of the feature maps produced by the convolutional layers, thus knowing the input image size matters.

# %% [markdown]
# ### 2.2 The training loop
#
# **(1 point)**
#
# You have already seen quite a few training loops in the preparations. Below we provide you with an example of a basic one that you can use.
# You need to provide an implementation that maps network outputs (probabilites) to hard labels.
#
# An extra point is awarded if you provide a vectorised implementation.

# %%
def output_to_label(z):
    """Map network output z to a hard label {0, 1}
    
    Args:
        z (Tensor): Probabilities for each sample in a batch.
    Returns:
        c (Tensor): Hard label {0, 1} for each sample in a batch
    """

    # YOUR CODE HERE
    # since sigmoid activation function, for Probabilities >= 0.5, it is a dog, for Probabilities < 0.5, it is a cat, 
    c = (z >= 0.5).long()
    return c

def test_output_to_label(fn):
    batch_size = torch.randint(1, 64, (1,))
    random_logits = torch.rand(batch_size)
    random_probs = random_logits / random_logits.sum()
    labels = fn(random_probs)
    assert labels.shape == random_logits.shape, "The element-wise function should preserve the shape"
    assert labels.dtype == torch.long, "Incorrect datatype, should be torch.long"
    fixed_logits = torch.tensor([0.1, 0.9, 0.51, 0.49, 0.7])
    fixed_labels = torch.tensor([0, 1, 1, 0, 1], dtype=torch.long)
    assert all(fixed_labels == fn(fixed_logits)), "Incorrect fixed output"
    assert fixed_logits.device == fixed_labels.device, "Make sure that the output tensor is on the same device"
    print("Test passed!")

test_output_to_label(output_to_label)
# Out:
# Test passed!

# %%
def training_loop(model, optimizer, loss_fn, train_loader, val_loader, num_epochs, print_every):
    print("Starting training")
    device = torch.device("cuda" if torch.cuda.is_available() 
                                  else "cpu")
    model.to(device)
    train_losses, train_accs, val_losses, val_accs = [], [], [], []

    for epoch in range(1, num_epochs+1):
        model, train_loss, train_acc = train_epoch(model,
                                                   optimizer,
                                                   loss_fn,
                                                   train_loader,
                                                   val_loader,
                                                   device,
                                                   print_every)
        val_loss, val_acc = validate(model, loss_fn, val_loader, device)
        print(f"Epoch {epoch}/{num_epochs}: "
              f"Train loss: {sum(train_loss)/len(train_loss):.3f}, "
              f"Train acc.: {sum(train_acc)/len(train_acc):.3f}, "
              f"Val. loss: {val_loss:.3f}, "
              f"Val. acc.: {val_acc:.3f}")
        train_losses.extend(train_loss)
        train_accs.extend(train_acc)
        val_losses.append(val_loss)
        val_accs.append(val_acc)
    return model, train_losses, train_accs, val_losses, val_accs

def train_epoch(model, optimizer, loss_fn, train_loader, val_loader, device, print_every):
    # Train:
    model.train()
    train_loss_batches, train_acc_batches = [], []
    num_batches = len(train_loader)
    for batch_index, (x, y) in enumerate(train_loader, 1):
        inputs, labels = x.to(device), y.to(device)
        optimizer.zero_grad()
        z = model.forward(inputs)
        loss = loss_fn(z, labels.float())
        loss.backward()
        optimizer.step()
        train_loss_batches.append(loss.item())

        hard_preds = output_to_label(z)
        acc_batch_avg = (hard_preds == labels).float().mean().item()
        train_acc_batches.append(acc_batch_avg)

        # If you want to print your progress more often than every epoch you can
        # set `print_every` to the number of batches you want between every status update.
        # Note that the print out will trigger a full validation on the full val. set => slows down training
        if print_every is not None and batch_index % print_every == 0:
            val_loss, val_acc = validate(model, loss_fn, val_loader, device)
            model.train()
            print(f"\tBatch {batch_index}/{num_batches}: "
                  f"\tTrain loss: {sum(train_loss_batches[-print_every:])/print_every:.3f}, "
                  f"\tTrain acc.: {sum(train_acc_batches[-print_every:])/print_every:.3f}, "
                  f"\tVal. loss: {val_loss:.3f}, "
                  f"\tVal. acc.: {val_acc:.3f}")

    return model, train_loss_batches, train_acc_batches

def validate(model, loss_fn, val_loader, device):
    val_loss_cum = 0
    val_acc_cum = 0
    model.eval()
    with torch.no_grad():
        for batch_index, (x, y) in enumerate(val_loader, 1):
            inputs, labels = x.to(device), y.to(device)
            z = model.forward(inputs)

            batch_loss = loss_fn(z, labels.float())
            val_loss_cum += batch_loss.item()
            hard_preds = output_to_label(z)
            acc_batch_avg = (hard_preds == labels).float().mean().item()
            val_acc_cum += acc_batch_avg
    return val_loss_cum/len(val_loader), val_acc_cum/len(val_loader)

# %% [markdown]
# **(1 point)**
#
# Use the training loop to train your model, using the two data loaders you created earlier. Train for a reasonable amount of epochs, so as to get a good sense of how well this architecture performs.
#
# Hints:
# - Training on a CPU is slow and in the beginning you just want to verify that your architecture actually produces a predicition with the correct shape. Make everything you can to speed up the prototyping phase, e.g. train only for a single epoch and make the images ridiculously small.

# %%
# YOUR CODE HERE
# loss_fn = nn.CrossEntropyLoss()
loss_fn = nn.BCELoss()

optimizer = torch.optim.Adam(model.parameters(), lr=1e-4)
num_epochs = 10

first_model, first_train_losses, first_train_accs, first_val_losses, first_val_accs = training_loop(model, optimizer, loss_fn, small_train_dataloader, small_val_dataloader, num_epochs=num_epochs, print_every=10)
# Out:
# Starting training
# 	Batch 10/55: 	Train loss: 0.693, 	Train acc.: 0.506, 	Val. loss: 0.690, 	Val. acc.: 0.540
# 	Batch 20/55: 	Train loss: 0.692, 	Train acc.: 0.517, 	Val. loss: 0.688, 	Val. acc.: 0.561
# 	Batch 30/55: 	Train loss: 0.691, 	Train acc.: 0.533, 	Val. loss: 0.686, 	Val. acc.: 0.569
# 	Batch 40/55: 	Train loss: 0.682, 	Train acc.: 0.598, 	Val. loss: 0.683, 	Val. acc.: 0.590
# 	Batch 50/55: 	Train loss: 0.683, 	Train acc.: 0.552, 	Val. loss: 0.681, 	Val. acc.: 0.574
# Epoch 1/10: Train loss: 0.688, Train acc.: 0.541, Val. loss: 0.679, Val. acc.: 0.577
# 	Batch 10/55: 	Train loss: 0.678, 	Train acc.: 0.588, 	Val. loss: 0.676, 	Val. acc.: 0.584
# 	Batch 20/55: 	Train loss: 0.670, 	Train acc.: 0.608, 	Val. loss: 0.671, 	Val. acc.: 0.601
# 	Batch 30/55: 	Train loss: 0.674, 	Train acc.: 0.591, 	Val. loss: 0.666, 	Val. acc.: 0.628
# 	Batch 40/55: 	Train loss: 0.663, 	Train acc.: 0.606, 	Val. loss: 0.663, 	Val. acc.: 0.630
# 	Batch 50/55: 	Train loss: 0.657, 	Train acc.: 0.627, 	Val. loss: 0.657, 	Val. acc.: 0.626
# Epoch 2/10: Train loss: 0.668, Train acc.: 0.608, Val. loss: 0.657, Val. acc.: 0.619
# 	Batch 10/55: 	Train loss: 0.655, 	Train acc.: 0.642, 	Val. loss: 0.651, 	Val. acc.: 0.638
# 	Batch 20/55: 	Train loss: 0.646, 	Train acc.: 0.634, 	Val. loss: 0.649, 	Val. acc.: 0.635
# 	Batch 30/55: 	Train loss: 0.643, 	Train acc.: 0.655, 	Val. loss: 0.644, 	Val. acc.: 0.641
# 	Batch 40/55: 	Train loss: 0.645, 	Train acc.: 0.623, 	Val. loss: 0.640, 	Val. acc.: 0.638
# 	Batch 50/55: 	Train loss: 0.640, 	Train acc.: 0.648, 	Val. loss: 0.640, 	Val. acc.: 0.651
# Epoch 3/10: Train loss: 0.645, Train acc.: 0.644, Val. loss: 0.637, Val. acc.: 0.649
# 	Batch 10/55: 	Train loss: 0.630, 	Train acc.: 0.655, 	Val. loss: 0.632, 	Val. acc.: 0.653
# 	Batch 20/55: 	Train loss: 0.630, 	Train acc.: 0.658, 	Val. loss: 0.628, 	Val. acc.: 0.655
# 	Batch 30/55: 	Train loss: 0.639, 	Train acc.: 0.623, 	Val. loss: 0.625, 	Val. acc.: 0.653
# 	Batch 40/55: 	Train loss: 0.620, 	Train acc.: 0.670, 	Val. loss: 0.625, 	Val. acc.: 0.653
# 	Batch 50/55: 	Train loss: 0.625, 	Train acc.: 0.647, 	Val. loss: 0.622, 	Val. acc.: 0.652
# Epoch 4/10: Train loss: 0.628, Train acc.: 0.652, Val. loss: 0.620, Val. acc.: 0.659
# 	Batch 10/55: 	Train loss: 0.619, 	Train acc.: 0.659, 	Val. loss: 0.619, 	Val. acc.: 0.660
# 	Batch 20/55: 	Train loss: 0.613, 	Train acc.: 0.673, 	Val. loss: 0.623, 	Val. acc.: 0.665
# 	Batch 30/55: 	Train loss: 0.615, 	Train acc.: 0.672, 	Val. loss: 0.615, 	Val. acc.: 0.665
# 	Batch 40/55: 	Train loss: 0.625, 	Train acc.: 0.642, 	Val. loss: 0.615, 	Val. acc.: 0.663
# 	Batch 50/55: 	Train loss: 0.603, 	Train acc.: 0.669, 	Val. loss: 0.613, 	Val. acc.: 0.660
# Epoch 5/10: Train loss: 0.613, Train acc.: 0.667, Val. loss: 0.615, Val. acc.: 0.649
# 	Batch 10/55: 	Train loss: 0.613, 	Train acc.: 0.650, 	Val. loss: 0.614, 	Val. acc.: 0.660
# 	Batch 20/55: 	Train loss: 0.594, 	Train acc.: 0.697, 	Val. loss: 0.610, 	Val. acc.: 0.660
# 	Batch 30/55: 	Train loss: 0.608, 	Train acc.: 0.669, 	Val. loss: 0.609, 	Val. acc.: 0.665
# 	Batch 40/55: 	Train loss: 0.615, 	Train acc.: 0.641, 	Val. loss: 0.607, 	Val. acc.: 0.666
# 	Batch 50/55: 	Train loss: 0.593, 	Train acc.: 0.695, 	Val. loss: 0.606, 	Val. acc.: 0.660
# Epoch 6/10: Train loss: 0.604, Train acc.: 0.669, Val. loss: 0.620, Val. acc.: 0.673
# 	Batch 10/55: 	Train loss: 0.610, 	Train acc.: 0.667, 	Val. loss: 0.605, 	Val. acc.: 0.668
# 	Batch 20/55: 	Train loss: 0.592, 	Train acc.: 0.703, 	Val. loss: 0.604, 	Val. acc.: 0.666
# 	Batch 30/55: 	Train loss: 0.590, 	Train acc.: 0.688, 	Val. loss: 0.604, 	Val. acc.: 0.664
# 	Batch 40/55: 	Train loss: 0.586, 	Train acc.: 0.697, 	Val. loss: 0.604, 	Val. acc.: 0.669
# 	Batch 50/55: 	Train loss: 0.603, 	Train acc.: 0.673, 	Val. loss: 0.602, 	Val. acc.: 0.671
# Epoch 7/10: Train loss: 0.596, Train acc.: 0.686, Val. loss: 0.603, Val. acc.: 0.665
# 	Batch 10/55: 	Train loss: 0.568, 	Train acc.: 0.711, 	Val. loss: 0.601, 	Val. acc.: 0.672
# 	Batch 20/55: 	Train loss: 0.585, 	Train acc.: 0.692, 	Val. loss: 0.599, 	Val. acc.: 0.679
# 	Batch 30/55: 	Train loss: 0.599, 	Train acc.: 0.669, 	Val. loss: 0.597, 	Val. acc.: 0.683
# 	Batch 40/55: 	Train loss: 0.599, 	Train acc.: 0.700, 	Val. loss: 0.600, 	Val. acc.: 0.674
# 	Batch 50/55: 	Train loss: 0.580, 	Train acc.: 0.678, 	Val. loss: 0.598, 	Val. acc.: 0.672
# Epoch 8/10: Train loss: 0.589, Train acc.: 0.687, Val. loss: 0.597, Val. acc.: 0.672
# 	Batch 10/55: 	Train loss: 0.560, 	Train acc.: 0.727, 	Val. loss: 0.596, 	Val. acc.: 0.672
# 	Batch 20/55: 	Train loss: 0.597, 	Train acc.: 0.683, 	Val. loss: 0.597, 	Val. acc.: 0.677
# 	Batch 30/55: 	Train loss: 0.594, 	Train acc.: 0.689, 	Val. loss: 0.608, 	Val. acc.: 0.676
# 	Batch 40/55: 	Train loss: 0.572, 	Train acc.: 0.709, 	Val. loss: 0.597, 	Val. acc.: 0.675
# 	Batch 50/55: 	Train loss: 0.570, 	Train acc.: 0.706, 	Val. loss: 0.594, 	Val. acc.: 0.682
# Epoch 9/10: Train loss: 0.579, Train acc.: 0.702, Val. loss: 0.595, Val. acc.: 0.675
# 	Batch 10/55: 	Train loss: 0.577, 	Train acc.: 0.697, 	Val. loss: 0.592, 	Val. acc.: 0.684
# 	Batch 20/55: 	Train loss: 0.587, 	Train acc.: 0.698, 	Val. loss: 0.592, 	Val. acc.: 0.676
# 	Batch 30/55: 	Train loss: 0.576, 	Train acc.: 0.684, 	Val. loss: 0.592, 	Val. acc.: 0.678
# 	Batch 40/55: 	Train loss: 0.582, 	Train acc.: 0.716, 	Val. loss: 0.595, 	Val. acc.: 0.678
# 	Batch 50/55: 	Train loss: 0.553, 	Train acc.: 0.720, 	Val. loss: 0.593, 	Val. acc.: 0.681
# Epoch 10/10: Train loss: 0.573, Train acc.: 0.704, Val. loss: 0.590, Val. acc.: 0.684

# %% [markdown]
# ### 2.3 Visualisation
#
# **(1 point)**
#
# Create two plots. In one of them, plot the loss in the training and the validation datasets. In the other one, plot the accuracy in the training and validation datasets.
# Note that the given training loop produces metrics at different intervals for training and validation, make sure that you align your metrics in a way that makes sense.

# %%
# YOUR CODE HERE
def window_average(array, dataloader):
    num_sets = len(array) // len(dataloader)
    # Initialize an empty list to store the average values
    averages = []
    # Iterate through the array and calculate averages
    for i in range(num_sets):
        start_index = i * len(dataloader)
        end_index = (i + 1) * len(dataloader)
        subset = array[start_index:end_index]
        avg = np.mean(subset)
        averages.append(avg)     
    return averages

first_train_losses_window_average = window_average(first_train_losses, small_train_dataloader)
first_train_accs_window_average = window_average(first_train_accs, small_train_dataloader)

fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(12,5))
x = np.arange(1,num_epochs+1)

ax1.plot(x, first_train_losses_window_average, label='Training Loss')
ax1.plot(x, first_val_losses, label='Validation Loss')
ax1.set_title('Loss Over Epochs (first_model)')
ax1.set_xlabel('Epoch')
ax1.set_ylabel('Loss')
ax1.set_xticks(x)
ax1.legend()

ax2.plot(x, first_train_accs_window_average, label='Training Accuracy')
ax2.plot(x, first_val_accs, label='Validation Accuracy')
ax2.set_title('Accurancy Over Epochs (first_model)')
ax2.set_xlabel('Epoch')
ax2.set_ylabel('Accuracy')
ax2.set_xticks(x)
ax2.legend()

plt.show()

# %% [markdown]
# **(2 points)**
#
# Based on these, what would you suggest for improving your model? Why?

# %% [markdown]
# **Your answer:**
# 1. The first model has a high bias, after 10 epochs, we got roughly 70% accuracy which is far from satisfying, a bigger network and new network architecture can be explored to get higher performance.
# 2. we can also try to fine tuning a pre-trained model which has higher performance and has been trained by similar dataset.

# %% [markdown]
# [Save your model](https://pytorch.org/tutorials/beginner/saving_loading_models.html) to disk (the architecture, weights, optimizer state, losses and accuracies). This is simply so you can use it again easily in the later parts of the notebook, without having to keep it in memory or re-training it. The actual file you create is not relevant to your submission. The code to save the model is given in the cell below.

# %%
# Assuming that you named your model "first_model"
torch.save({'model_state_dict': first_model.state_dict(),
            'train_losses': first_train_losses,
            'train_accs': first_train_accs,
            'val_losses': first_val_losses,
            'val_accs': first_val_accs,
            }, "./first_model.ckpt")

# Example of creating and initialising model with a previously saved state dict:
saved_first_model = FirstCnn(img_size) # fill-in the arguments if needed
checkpoint = torch.load("first_model.ckpt")
saved_first_model.load_state_dict(checkpoint['model_state_dict'])

# Example of re-using saved statistics:
print("Validation accuracies:", checkpoint['val_accs'])
# Out:
# Validation accuracies: [0.5767299110690752, 0.6190476194024086, 0.6494605665405592, 0.6588541691501936, 0.6490885441501936, 0.673363097012043, 0.6650855665405592, 0.6717819944024086, 0.6748511915405592, 0.6840587804714838]

# %% [markdown]
# ---
# ## 3. Improving your model

# %% [markdown]
# **(3 points)**
#
# Now you are free to create whichever model you want. A simple improvement based on your analysis of the above results is fine, or you can do something more ambitious. When you're happy with one architecture, copy it in the cell below and train it here. Save the training and validation losses and accuracies. You'll use this later to compare your best model with the one using transfer learning. *Hint*: reducing the input image size facilitates training.
#
# **Note**: When trying different ideas, you'll end up with several different models. However, when submitting your solutions to Canvas, the cell below must contain only the definition and training of *one* model. Remove all code related to the models that were not chosen.

# %%
# YOUR CODE HERE
class SecondCnn(nn.Module):
    def __init__(self, img_size):
        super().__init__() 
        self.img_size = img_size
        self.conv1 = nn.Conv2d(in_channels=3, out_channels=64, kernel_size=3, stride=1, padding=1)
        self.bn1 = nn.BatchNorm2d(64)
        self.pool1 = nn.MaxPool2d(2,2)
        self.drouput1 = nn.Dropout(0.2)

        self.conv2 = nn.Conv2d(in_channels=64, out_channels=128, kernel_size=3, stride=1, padding=1)
        self.bn2 = nn.BatchNorm2d(128)
        self.pool2 = nn.MaxPool2d(2,2)
        self.drouput2 = nn.Dropout(0.2)

        self.conv3 = nn.Conv2d(in_channels=128, out_channels=256, kernel_size=3, stride=1, padding=1)
        self.bn3 = nn.BatchNorm2d(256)
        self.pool3 = nn.MaxPool2d(2,2)
        self.drouput3 = nn.Dropout(0.2)

        self.fc1 = nn.Linear(self._output_size(), 512)
        self.fc2 = nn.Linear(512, 1)
        self.sigmoid = nn.Sigmoid()

    def forward(self, input_batch):
        
        x = F.relu(self.bn1(self.conv1(input_batch)))
        x = self.drouput1(self.pool1(x))

        x = F.relu(self.bn2(self.conv2(x)))
        x = self.drouput2(self.pool2(x))

        x = F.relu(self.bn3(self.conv3(x)))
        x = self.drouput3(self.pool3(x))

        x = x.view(-1, self._output_size())
        x = self.fc1(x)
        x = self.sigmoid(self.fc2(x))
        # x = self.fc1(x)

        return x.squeeze()

    def _output_size(self):
        # calculate the output size after 2 convolutional layer and 1 pooling layer
        conv1_W_H = (self.img_size - 3 + 2 * 1) / 1 + 1
        maxpool1_W_H = (conv1_W_H - 2) / 2 + 1

        conv2_W_H = (maxpool1_W_H - 3 + 2 * 1) / 1 + 1
        maxpool2_W_H = (conv2_W_H - 2) / 2 + 1

        conv3_W_H = (maxpool2_W_H - 3 + 2 * 1) / 1 + 1
        maxpool2_W_H = (conv3_W_H - 2) / 2 + 1

        return int(maxpool2_W_H * maxpool2_W_H * 256)


img_size = 64
batch_size = 64

second_model = SecondCnn(img_size)  
print(second_model)
# Out:
# SecondCnn(
#   (conv1): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (pool1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (drouput1): Dropout(p=0.2, inplace=False)
#   (conv2): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (pool2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (drouput2): Dropout(p=0.2, inplace=False)
#   (conv3): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (pool3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (drouput3): Dropout(p=0.2, inplace=False)
#   (fc1): Linear(in_features=16384, out_features=512, bias=True)
#   (fc2): Linear(in_features=512, out_features=1, bias=True)
#   (sigmoid): Sigmoid()
# )

# %%
loss_fn2 = nn.BCELoss()
optimizer2 = torch.optim.Adam(second_model.parameters(), lr=1e-4)
num_epochs = 10

impr_model, impr_train_losses, impr_train_accs, impr_val_losses, impr_val_accs = training_loop(second_model, optimizer2, loss_fn2, small_train_dataloader, small_val_dataloader, num_epochs=num_epochs, print_every=10)
# Out:
# Starting training
# 	Batch 10/55: 	Train loss: 5.871, 	Train acc.: 0.491, 	Val. loss: 0.856, 	Val. acc.: 0.512
# 	Batch 20/55: 	Train loss: 2.668, 	Train acc.: 0.514, 	Val. loss: 0.870, 	Val. acc.: 0.544
# 	Batch 30/55: 	Train loss: 1.271, 	Train acc.: 0.545, 	Val. loss: 0.808, 	Val. acc.: 0.562
# 	Batch 40/55: 	Train loss: 0.919, 	Train acc.: 0.580, 	Val. loss: 0.633, 	Val. acc.: 0.649
# 	Batch 50/55: 	Train loss: 0.842, 	Train acc.: 0.600, 	Val. loss: 0.622, 	Val. acc.: 0.649
# Epoch 1/10: Train loss: 2.167, Train acc.: 0.551, Val. loss: 0.653, Val. acc.: 0.625
# 	Batch 10/55: 	Train loss: 0.618, 	Train acc.: 0.662, 	Val. loss: 0.609, 	Val. acc.: 0.677
# 	Batch 20/55: 	Train loss: 0.617, 	Train acc.: 0.661, 	Val. loss: 0.633, 	Val. acc.: 0.642
# 	Batch 30/55: 	Train loss: 0.614, 	Train acc.: 0.681, 	Val. loss: 0.606, 	Val. acc.: 0.656
# 	Batch 40/55: 	Train loss: 0.649, 	Train acc.: 0.614, 	Val. loss: 0.616, 	Val. acc.: 0.667
# 	Batch 50/55: 	Train loss: 0.659, 	Train acc.: 0.636, 	Val. loss: 0.584, 	Val. acc.: 0.680
# Epoch 2/10: Train loss: 0.626, Train acc.: 0.658, Val. loss: 0.577, Val. acc.: 0.703
# 	Batch 10/55: 	Train loss: 0.600, 	Train acc.: 0.700, 	Val. loss: 0.587, 	Val. acc.: 0.687
# 	Batch 20/55: 	Train loss: 0.605, 	Train acc.: 0.672, 	Val. loss: 0.594, 	Val. acc.: 0.688
# 	Batch 30/55: 	Train loss: 0.611, 	Train acc.: 0.655, 	Val. loss: 0.586, 	Val. acc.: 0.696
# 	Batch 40/55: 	Train loss: 0.565, 	Train acc.: 0.730, 	Val. loss: 0.674, 	Val. acc.: 0.639
# 	Batch 50/55: 	Train loss: 0.582, 	Train acc.: 0.708, 	Val. loss: 0.567, 	Val. acc.: 0.688
# Epoch 3/10: Train loss: 0.594, Train acc.: 0.689, Val. loss: 0.597, Val. acc.: 0.684
# 	Batch 10/55: 	Train loss: 0.543, 	Train acc.: 0.723, 	Val. loss: 0.583, 	Val. acc.: 0.685
# 	Batch 20/55: 	Train loss: 0.578, 	Train acc.: 0.722, 	Val. loss: 0.592, 	Val. acc.: 0.696
# 	Batch 30/55: 	Train loss: 0.550, 	Train acc.: 0.738, 	Val. loss: 0.550, 	Val. acc.: 0.722
# 	Batch 40/55: 	Train loss: 0.507, 	Train acc.: 0.752, 	Val. loss: 0.544, 	Val. acc.: 0.721
# 	Batch 50/55: 	Train loss: 0.564, 	Train acc.: 0.716, 	Val. loss: 0.533, 	Val. acc.: 0.740
# Epoch 4/10: Train loss: 0.552, Train acc.: 0.728, Val. loss: 0.592, Val. acc.: 0.684
# 	Batch 10/55: 	Train loss: 0.626, 	Train acc.: 0.667, 	Val. loss: 0.546, 	Val. acc.: 0.726
# 	Batch 20/55: 	Train loss: 0.598, 	Train acc.: 0.694, 	Val. loss: 0.678, 	Val. acc.: 0.652
# 	Batch 30/55: 	Train loss: 0.596, 	Train acc.: 0.697, 	Val. loss: 0.568, 	Val. acc.: 0.711
# 	Batch 40/55: 	Train loss: 0.596, 	Train acc.: 0.706, 	Val. loss: 0.559, 	Val. acc.: 0.714
# 	Batch 50/55: 	Train loss: 0.550, 	Train acc.: 0.748, 	Val. loss: 0.535, 	Val. acc.: 0.731
# Epoch 5/10: Train loss: 0.584, Train acc.: 0.707, Val. loss: 0.524, Val. acc.: 0.750
# 	Batch 10/55: 	Train loss: 0.493, 	Train acc.: 0.756, 	Val. loss: 0.630, 	Val. acc.: 0.675
# 	Batch 20/55: 	Train loss: 0.514, 	Train acc.: 0.745, 	Val. loss: 0.545, 	Val. acc.: 0.721
# 	Batch 30/55: 	Train loss: 0.498, 	Train acc.: 0.772, 	Val. loss: 0.575, 	Val. acc.: 0.716
# 	Batch 40/55: 	Train loss: 0.542, 	Train acc.: 0.728, 	Val. loss: 0.522, 	Val. acc.: 0.752
# 	Batch 50/55: 	Train loss: 0.519, 	Train acc.: 0.744, 	Val. loss: 0.563, 	Val. acc.: 0.711
# Epoch 6/10: Train loss: 0.512, Train acc.: 0.750, Val. loss: 0.515, Val. acc.: 0.747
# 	Batch 10/55: 	Train loss: 0.456, 	Train acc.: 0.797, 	Val. loss: 0.575, 	Val. acc.: 0.707
# 	Batch 20/55: 	Train loss: 0.489, 	Train acc.: 0.777, 	Val. loss: 0.502, 	Val. acc.: 0.755
# 	Batch 30/55: 	Train loss: 0.500, 	Train acc.: 0.758, 	Val. loss: 0.530, 	Val. acc.: 0.734
# 	Batch 40/55: 	Train loss: 0.434, 	Train acc.: 0.808, 	Val. loss: 0.502, 	Val. acc.: 0.760
# 	Batch 50/55: 	Train loss: 0.478, 	Train acc.: 0.773, 	Val. loss: 0.702, 	Val. acc.: 0.653
# Epoch 7/10: Train loss: 0.483, Train acc.: 0.777, Val. loss: 0.521, Val. acc.: 0.752
# 	Batch 10/55: 	Train loss: 0.505, 	Train acc.: 0.744, 	Val. loss: 0.490, 	Val. acc.: 0.760
# 	Batch 20/55: 	Train loss: 0.443, 	Train acc.: 0.794, 	Val. loss: 0.543, 	Val. acc.: 0.729
# 	Batch 30/55: 	Train loss: 0.446, 	Train acc.: 0.798, 	Val. loss: 0.484, 	Val. acc.: 0.773
# 	Batch 40/55: 	Train loss: 0.491, 	Train acc.: 0.784, 	Val. loss: 0.503, 	Val. acc.: 0.764
# 	Batch 50/55: 	Train loss: 0.512, 	Train acc.: 0.752, 	Val. loss: 0.699, 	Val. acc.: 0.685
# Epoch 8/10: Train loss: 0.478, Train acc.: 0.773, Val. loss: 0.544, Val. acc.: 0.743
# 	Batch 10/55: 	Train loss: 0.444, 	Train acc.: 0.784, 	Val. loss: 0.526, 	Val. acc.: 0.744
# 	Batch 20/55: 	Train loss: 0.418, 	Train acc.: 0.816, 	Val. loss: 0.616, 	Val. acc.: 0.706
# 	Batch 30/55: 	Train loss: 0.417, 	Train acc.: 0.794, 	Val. loss: 0.473, 	Val. acc.: 0.781
# 	Batch 40/55: 	Train loss: 0.395, 	Train acc.: 0.828, 	Val. loss: 0.501, 	Val. acc.: 0.760
# 	Batch 50/55: 	Train loss: 0.457, 	Train acc.: 0.780, 	Val. loss: 0.576, 	Val. acc.: 0.733
# Epoch 9/10: Train loss: 0.432, Train acc.: 0.801, Val. loss: 0.501, Val. acc.: 0.761
# 	Batch 10/55: 	Train loss: 0.426, 	Train acc.: 0.809, 	Val. loss: 0.535, 	Val. acc.: 0.761
# 	Batch 20/55: 	Train loss: 0.374, 	Train acc.: 0.819, 	Val. loss: 0.479, 	Val. acc.: 0.779
# 	Batch 30/55: 	Train loss: 0.475, 	Train acc.: 0.767, 	Val. loss: 0.464, 	Val. acc.: 0.780
# 	Batch 40/55: 	Train loss: 0.490, 	Train acc.: 0.764, 	Val. loss: 0.486, 	Val. acc.: 0.780
# 	Batch 50/55: 	Train loss: 0.431, 	Train acc.: 0.803, 	Val. loss: 0.572, 	Val. acc.: 0.730
# Epoch 10/10: Train loss: 0.432, Train acc.: 0.799, Val. loss: 0.492, Val. acc.: 0.758

# %% [markdown]
# **(1 point)**
#
# Create two plots. In one of them, plot the loss in the training and the validation datasets. In the other one, plot the accuracy in the training and validation datasets.

# %%
# YOUR CODE HERE
impr_train_losses_window_average = window_average(impr_train_losses, small_train_dataloader)
impr_train_accs_window_average = window_average(impr_train_accs, small_train_dataloader)

fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(12,5))
x = np.arange(1,num_epochs+1)

ax1.plot(x, impr_train_losses_window_average, label='Training Loss')
ax1.plot(x, impr_val_losses, label='Validation Loss')
ax1.set_title('Loss Over Epochs (impr_model)')
ax1.set_xlabel('Epoch')
ax1.set_ylabel('Loss')
ax1.set_xticks(x)
ax1.legend()

ax2.plot(x, impr_train_accs_window_average, label='Training Accuracy')
ax2.plot(x, impr_val_accs, label='Validation Accuracy')
ax2.set_title('Accurancy Over Epochs (impr_model)')
ax2.set_xlabel('Epoch')
ax2.set_ylabel('Accuracy')
ax2.set_xticks(x)
ax2.legend()

plt.show()

# %% [markdown]
# **(1 point)**
#
# How does the model perform, compared to the first CNN model? Create one plot with the training accuracy and another with the validation accuracy of the two models.

# %%
# YOUR CODE HERE
# YOUR CODE HERE
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(12,5))
x = np.arange(1,num_epochs+1)

ax1.plot(x, first_train_accs_window_average, label='first_model')
ax1.plot(x, impr_train_accs_window_average, label='impr_model')
ax1.set_title('Training accuracy (first_model vs. impr_model)')
ax1.set_xlabel('Epoch')
ax1.set_ylabel('Accuracy')
ax1.set_xticks(x)
ax1.legend()

ax2.plot(x, first_val_accs, label='first_model')
ax2.plot(x, impr_val_accs, label='impr_model')
ax2.set_title('Validation accurancy (first_model vs. impr_model)')
ax2.set_xlabel('Epoch')
ax2.set_ylabel('Accuracy')
ax2.set_xticks(x)
ax2.legend()

plt.show()

# %% [markdown]
# **(3 points)**
#
# Did your results improve? What problems did your improvements fix? Explain why, or why not.

# %% [markdown]
# **Your answer:**
#
# By training the improved model (impr_model), we achieve approximately a 10% improvement in accuracy on both the training and validation datasets. This improvement can be attributed to the utilization of a more complex neural network capable of capturing a more range of image features and edges.

# %% [markdown]
# Save your model to disk.

# %%
# Assuming that you named your model "impr_model"
torch.save({'model_state_dict': impr_model.state_dict(),
            'train_losses': impr_train_losses,
            'train_accs': impr_train_accs,
            'val_losses': impr_val_losses,
            'val_accs': impr_val_accs,
            }, "./improved_model.ckpt")

# %%
# YOUR CODE HERE

# %% [markdown]
# ---
# ## 4. Transfer Learning

# %% [markdown]
# **From now, training on a CPU will likely not be feasible. If your computer has a GPU, try it out! Otherwise, now is the time to connect to your cloud instance**
#
# Now, instead of trying to come up with a good architecture for this task, we'll use the VGG16 architecture, but with the top layers removed (the fully connected layers + softmax). We'll substitute them with our own top network, designed for dog/cat classification.
# This top network is often called the "head" in transfer learning.
#
# However, this model has a very high capacity, and will probably suffer a lot from overfitting if we try to train it from scratch, using only our small subset of data. Instead, we'll start the optimization with the weights obtained after training VGG16 on the ImageNet dataset.
#
# Start by loading the *pretrained* VGG16 model, from the [torchvision.models](https://pytorch.org/vision/stable/models.html?highlight=vgg#torchvision.models.vgg16).

# %%
from torchvision import models
vgg_model = models.vgg16(weights=models.VGG16_Weights)
print(vgg_model.classifier)
# Out:
# Sequential(
#   (0): Linear(in_features=25088, out_features=4096, bias=True)
#   (1): ReLU(inplace=True)
#   (2): Dropout(p=0.5, inplace=False)
#   (3): Linear(in_features=4096, out_features=4096, bias=True)
#   (4): ReLU(inplace=True)
#   (5): Dropout(p=0.5, inplace=False)
#   (6): Linear(in_features=4096, out_features=1000, bias=True)
# )

# %% [markdown]
# **(1 point)**
#
# Create a new model as a so-called head network to the base VGG model.
# VGG is a relatively deep network so think about what would be a reasonable model head for transfer learning.
#
# *Hint:*
# - You can access and modify the top layers of the VGG model with `vgg_model.classifier`, and the remaining layers with `vgg_model.features`.
# - You can get the number of output features of `vgg_model.features` with `vgg_model.classifier[0].in_features`

# %%
# YOUR CODE HERE

# The VGG-16 model typically consists of two parts: features and classifier. 
# The "features" part contains convolutional layers,
# while the "classifier" part contains fully connected layers for classification tasks.
vgg_base = vgg_model.features

num_features = vgg_model.classifier[0].in_features

custom_head_layers = nn.Sequential(
    nn.Linear(num_features,512),
    nn.BatchNorm1d(512),
    nn.ReLU(),
    nn.Linear(512, 1),
    nn.Sigmoid()
)

# %% [markdown]
# **(2 points)**
#
# Now add the new model on top of VGG.

# %%
# YOUR CODE HERE
vgg_model_new = nn.Sequential(
    vgg_base,
    nn.Flatten(),
    custom_head_layers,
    nn.Flatten(start_dim=0)
)

# %% [markdown]
# ### 4.1 Using VGG features

# %% [markdown]
# **(1 point)**
#
# Now we're almost ready to train the new model. For transfer learning we want to freeze all but the top layers in your architecture (i.e. signal to the optimizer that the bottom layers should not be changed during optimization) by setting the attribute `requires_grad` for all parameters `vgg_model.features` to `False`.

# %%
# YOUR CODE HERE
for param in vgg_base.parameters():
    param.require_grad = False

# %% [markdown]
# **(1 point)**
#
# Prepare dataloaders for transfer learning. Don't forget that the VGG network is specialised for images of a certain size.

# %%
# YOUR CODE HERE
small_train_dataset_vgg = DogsCatsData(small_train_path, transform3)
small_val_dataset_vgg = DogsCatsData(small_val_path, transform3)

train_dataloader = DataLoader(small_train_dataset_vgg, batch_size=64, shuffle=True)
val_dataloader = DataLoader(small_val_dataset_vgg, batch_size=64)


def test_dataloader_for_VGG(dataloader):
    img_height, img_width = next(iter(train_dataloader))[0].shape[2:4]
    assert img_height == 224, "Image height is not suitable for VGG."
    assert img_width == 224, "Image width is not suitable for VGG."
    print("Test passed!")

# Assuming you created train_dataloader and val_dataloader
test_dataloader_for_VGG(train_dataloader)
test_dataloader_for_VGG(val_dataloader)
# Out:
# Test passed!
# Test passed!

# %% [markdown]
# **(1 point)**
#
# Perform the transfer learning by training the top layers of your model.

# %%
# YOUR CODE HERE
loss_fn_vgg = nn.BCELoss()
optimizer_vgg = torch.optim.Adam(vgg_model_new.parameters(), lr=1e-4)
num_epochs = 10

vgg_model_transfer, vgg_train_losses, vgg_train_accs, vgg_val_losses, vgg_val_accs =  training_loop(vgg_model_new, optimizer_vgg, loss_fn_vgg, train_dataloader, val_dataloader, num_epochs=num_epochs, print_every=10)
# Out:
# Starting training
# 	Batch 10/55: 	Train loss: 0.222, 	Train acc.: 0.905, 	Val. loss: 0.128, 	Val. acc.: 0.978
# 	Batch 20/55: 	Train loss: 0.105, 	Train acc.: 0.959, 	Val. loss: 0.192, 	Val. acc.: 0.954
# 	Batch 30/55: 	Train loss: 0.099, 	Train acc.: 0.963, 	Val. loss: 0.114, 	Val. acc.: 0.985
# 	Batch 40/55: 	Train loss: 0.081, 	Train acc.: 0.970, 	Val. loss: 0.108, 	Val. acc.: 0.985
# 	Batch 50/55: 	Train loss: 0.039, 	Train acc.: 0.981, 	Val. loss: 0.105, 	Val. acc.: 0.984
# Epoch 1/10: Train loss: 0.104, Train acc.: 0.959, Val. loss: 0.112, Val. acc.: 0.982
# 	Batch 10/55: 	Train loss: 0.024, 	Train acc.: 0.992, 	Val. loss: 0.110, 	Val. acc.: 0.980
# 	Batch 20/55: 	Train loss: 0.025, 	Train acc.: 0.991, 	Val. loss: 0.107, 	Val. acc.: 0.986
# 	Batch 30/55: 	Train loss: 0.011, 	Train acc.: 0.997, 	Val. loss: 0.101, 	Val. acc.: 0.987
# 	Batch 40/55: 	Train loss: 0.011, 	Train acc.: 0.994, 	Val. loss: 0.109, 	Val. acc.: 0.989
# 	Batch 50/55: 	Train loss: 0.014, 	Train acc.: 0.994, 	Val. loss: 0.108, 	Val. acc.: 0.987
# Epoch 2/10: Train loss: 0.017, Train acc.: 0.993, Val. loss: 0.160, Val. acc.: 0.986
# 	Batch 10/55: 	Train loss: 0.010, 	Train acc.: 0.997, 	Val. loss: 0.179, 	Val. acc.: 0.982
# 	Batch 20/55: 	Train loss: 0.026, 	Train acc.: 0.995, 	Val. loss: 0.165, 	Val. acc.: 0.984
# 	Batch 30/55: 	Train loss: 0.025, 	Train acc.: 0.991, 	Val. loss: 0.116, 	Val. acc.: 0.980
# 	Batch 40/55: 	Train loss: 0.019, 	Train acc.: 0.994, 	Val. loss: 0.201, 	Val. acc.: 0.956
# 	Batch 50/55: 	Train loss: 0.032, 	Train acc.: 0.989, 	Val. loss: 0.171, 	Val. acc.: 0.981
# Epoch 3/10: Train loss: 0.021, Train acc.: 0.994, Val. loss: 0.125, Val. acc.: 0.978
# 	Batch 10/55: 	Train loss: 0.014, 	Train acc.: 0.995, 	Val. loss: 0.123, 	Val. acc.: 0.981
# 	Batch 20/55: 	Train loss: 0.007, 	Train acc.: 0.995, 	Val. loss: 0.185, 	Val. acc.: 0.967
# 	Batch 30/55: 	Train loss: 0.034, 	Train acc.: 0.991, 	Val. loss: 0.126, 	Val. acc.: 0.973
# 	Batch 40/55: 	Train loss: 0.022, 	Train acc.: 0.994, 	Val. loss: 0.129, 	Val. acc.: 0.979
# 	Batch 50/55: 	Train loss: 0.015, 	Train acc.: 0.994, 	Val. loss: 0.135, 	Val. acc.: 0.978
# Epoch 4/10: Train loss: 0.018, Train acc.: 0.994, Val. loss: 0.177, Val. acc.: 0.983
# 	Batch 10/55: 	Train loss: 0.003, 	Train acc.: 1.000, 	Val. loss: 0.130, 	Val. acc.: 0.982
# 	Batch 20/55: 	Train loss: 0.039, 	Train acc.: 0.989, 	Val. loss: 0.122, 	Val. acc.: 0.980
# 	Batch 30/55: 	Train loss: 0.019, 	Train acc.: 0.994, 	Val. loss: 0.131, 	Val. acc.: 0.974
# 	Batch 40/55: 	Train loss: 0.025, 	Train acc.: 0.991, 	Val. loss: 0.115, 	Val. acc.: 0.979
# 	Batch 50/55: 	Train loss: 0.012, 	Train acc.: 0.997, 	Val. loss: 0.122, 	Val. acc.: 0.979
# Epoch 5/10: Train loss: 0.018, Train acc.: 0.995, Val. loss: 0.132, Val. acc.: 0.982
# 	Batch 10/55: 	Train loss: 0.010, 	Train acc.: 0.997, 	Val. loss: 0.118, 	Val. acc.: 0.981
# 	Batch 20/55: 	Train loss: 0.009, 	Train acc.: 0.997, 	Val. loss: 0.119, 	Val. acc.: 0.980
# 	Batch 30/55: 	Train loss: 0.006, 	Train acc.: 0.998, 	Val. loss: 0.143, 	Val. acc.: 0.978
# 	Batch 40/55: 	Train loss: 0.001, 	Train acc.: 1.000, 	Val. loss: 0.174, 	Val. acc.: 0.987
# 	Batch 50/55: 	Train loss: 0.003, 	Train acc.: 0.998, 	Val. loss: 0.155, 	Val. acc.: 0.975
# Epoch 6/10: Train loss: 0.006, Train acc.: 0.998, Val. loss: 0.174, Val. acc.: 0.983
# 	Batch 10/55: 	Train loss: 0.014, 	Train acc.: 0.997, 	Val. loss: 0.180, 	Val. acc.: 0.978
# 	Batch 20/55: 	Train loss: 0.022, 	Train acc.: 0.991, 	Val. loss: 0.195, 	Val. acc.: 0.977
# 	Batch 30/55: 	Train loss: 0.020, 	Train acc.: 0.997, 	Val. loss: 0.182, 	Val. acc.: 0.974
# 	Batch 40/55: 	Train loss: 0.015, 	Train acc.: 0.997, 	Val. loss: 0.216, 	Val. acc.: 0.948
# 	Batch 50/55: 	Train loss: 0.015, 	Train acc.: 0.995, 	Val. loss: 0.153, 	Val. acc.: 0.970
# Epoch 7/10: Train loss: 0.019, Train acc.: 0.995, Val. loss: 0.115, Val. acc.: 0.979
# 	Batch 10/55: 	Train loss: 0.029, 	Train acc.: 0.989, 	Val. loss: 0.164, 	Val. acc.: 0.966
# 	Batch 20/55: 	Train loss: 0.005, 	Train acc.: 0.998, 	Val. loss: 0.181, 	Val. acc.: 0.979
# 	Batch 30/55: 	Train loss: 0.007, 	Train acc.: 0.998, 	Val. loss: 0.210, 	Val. acc.: 0.978
# 	Batch 40/55: 	Train loss: 0.005, 	Train acc.: 0.998, 	Val. loss: 0.256, 	Val. acc.: 0.980
# 	Batch 50/55: 	Train loss: 0.029, 	Train acc.: 0.991, 	Val. loss: 0.129, 	Val. acc.: 0.977
# Epoch 8/10: Train loss: 0.015, Train acc.: 0.995, Val. loss: 0.123, Val. acc.: 0.977
# 	Batch 10/55: 	Train loss: 0.003, 	Train acc.: 1.000, 	Val. loss: 0.151, 	Val. acc.: 0.974
# 	Batch 20/55: 	Train loss: 0.002, 	Train acc.: 1.000, 	Val. loss: 0.136, 	Val. acc.: 0.983
# 	Batch 30/55: 	Train loss: 0.001, 	Train acc.: 1.000, 	Val. loss: 0.143, 	Val. acc.: 0.980
# 	Batch 40/55: 	Train loss: 0.002, 	Train acc.: 0.998, 	Val. loss: 0.178, 	Val. acc.: 0.976
# 	Batch 50/55: 	Train loss: 0.004, 	Train acc.: 0.998, 	Val. loss: 0.200, 	Val. acc.: 0.980
# Epoch 9/10: Train loss: 0.003, Train acc.: 0.999, Val. loss: 0.203, Val. acc.: 0.976
# 	Batch 10/55: 	Train loss: 0.002, 	Train acc.: 0.998, 	Val. loss: 0.144, 	Val. acc.: 0.981
# 	Batch 20/55: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.150, 	Val. acc.: 0.982
# 	Batch 30/55: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.157, 	Val. acc.: 0.981
# 	Batch 40/55: 	Train loss: 0.001, 	Train acc.: 1.000, 	Val. loss: 0.152, 	Val. acc.: 0.982
# 	Batch 50/55: 	Train loss: 0.002, 	Train acc.: 0.998, 	Val. loss: 0.211, 	Val. acc.: 0.980
# Epoch 10/10: Train loss: 0.002, Train acc.: 0.999, Val. loss: 0.125, Val. acc.: 0.984

# %% [markdown]
# **(1 point)**
#
# Create two plots. In one of them, plot the loss in the training and the validation datasets. In the other one, plot the accuracy in the training and validation datasets.

# %%
# YOUR CODE HERE
vgg_train_losses_window_average = window_average(vgg_train_losses, train_dataloader)
vgg_train_accs_window_average = window_average(vgg_train_accs, train_dataloader)

fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(12,5))
x = np.arange(1,num_epochs+1)

ax1.plot(x, vgg_train_losses_window_average, label='Training Loss')
ax1.plot(x, vgg_val_losses, label='Validation Loss')
ax1.set_title('Loss Over Epochs (vgg_transfer_model)')
ax1.set_xlabel('Epoch')
ax1.set_ylabel('Loss')
ax1.set_xticks(x)
ax1.legend()

ax2.plot(x, vgg_train_accs_window_average, label='Training Accuracy')
ax2.plot(x, vgg_val_accs, label='Validation Accuracy')
ax2.set_title('Accurancy Over Epochs (vgg_transfer_model)')
ax2.set_xlabel('Epoch')
ax2.set_ylabel('Accuracy')
ax2.set_xticks(x)
ax2.legend()

plt.show()

# %% [markdown]
# **(2 points)**
#
# How does the model perform, compared to the model obtained in step 3? Create one plot with the training accuracy and another with the validation accuracy of the two scenarios.

# %%
# YOUR CODE HERE
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(12,5))
x = np.arange(1,num_epochs+1)

ax1.plot(x, vgg_train_accs_window_average, label='vgg_transfer_model')
ax1.plot(x, impr_train_accs_window_average, label='impr_model')
ax1.set_title('Training accuracy (vgg_transfer_model vs. impr_model)')
ax1.set_xlabel('Epoch')
ax1.set_ylabel('Accuracy')
ax1.set_xticks(x)
ax1.legend()

ax2.plot(x, vgg_val_accs, label='vgg_transfer_model')
ax2.plot(x, impr_val_accs, label='impr_model')
ax2.set_title('Validation accurancy (vgg_transfer_model vs. impr_model)')
ax2.set_xlabel('Epoch')
ax2.set_ylabel('Accuracy')
ax2.set_xticks(x)
ax2.legend()

plt.show()

# %% [markdown]
# **(3 points)**
#
# Compare these results. Which approach worked best, starting from scratch or doing transfer learning? Reflect on whether your comparison is fair or not:

# %% [markdown]
# **Your answer:**
#
# 1. Comparing the results, we found that using transfer learning with the VGG model performed much better than training a model from scratch in this case.
# 2. However, it's important to note that the comparison may not be entirely fair. In transfer learning, we build a model based on a pre-trained VGG16 model, and the performance of the new model relies on the base model. Additionally, the resource requirements for training these two models differ. Training a VGG16 model can be resource-intensive, and we may not have considered this aspect during the comparison.
# 3. To make a fair comparison, we should take into account various factors, such as performance, resource usage, and task complexity, to determine which approach is more suitable for the given problem.

# %% [markdown]
# **(2 points)**
#
# What are the main differences between the ImageNet dataset and the Dogs vs Cats dataset we used?

# %% [markdown]
# **Your answer:**
#
# 1. ImageNet dataset includes a wide variety of image categories ( more than 20,000 categories), while Dogs vs. Cats only focus on two categories.
# 2. ImageNet dataset includes more than 14 million images, while Dogs vs. Cats dataset is a much smaller datase which has about 25K images.

# %% [markdown]
# **(2 points)**
#
# Even though there are considerable differences between these datasets, why is it that transfer learning is still a good idea?

# %% [markdown]
# **Your answer:**
#
# 1. vgg16 model trained on ImageNet dataset developed a generalization capability which can be used in a different task, even though the two dataset are very different.
# 2. Pre-trained models can learn important features from images. The initial layers can catch simple things like edges and textures, while the later layers can grasp more general features. These learned details can be useful for various tasks.
# 3. When we don't have much training data to train a deep learning model, we can fine-tune a pre-trained model on a smaller dataset.

# %% [markdown]
# **(1 point)**
#
# In which scenario would transfer learning be unsuitable?

# %% [markdown]
# **Your answer:**
#
# 1. When dataset used for pre-training and target dataset have significantly different distributions, transfer learning may not work well.
# 2. When the transfer learning are used for a totally different task from the pre-trained model, transfer learning may not work well.

# %% [markdown]
# Save the model to a file.

# %%
# YOUR CODE HERE
torch.save({'model_state_dict': vgg_model_transfer.state_dict(),
            'train_losses': vgg_train_losses,
            'train_accs': vgg_train_accs,
            'val_losses': vgg_val_losses,
            'val_accs': vgg_val_accs,
            }, "./vgg_model_transfer.ckpt")

# %% [markdown]
# ### 4.2 Fine-tuning

# %% [markdown]
# Now that we have a better starting point for the top layers, we can train the entire network. Unfreeze the bottom layers by resetting the `requires_grad` attribute to `True`.

# %%
# YOUR CODE HERE
for param in vgg_model_transfer.parameters():
    param.require_grad = True

# %% [markdown]
# **(1 point)**
#
# Fine tune the model by training all the layers.

# %%
# YOUR CODE HERE
loss_fn_fine_tuning = nn.BCELoss()
optimizer_fine_tuning = torch.optim.Adam(vgg_model_transfer.parameters(), lr=1e-5)
num_epochs = 10

vgg_model_fine_tuning, fine_tuning_train_losses, fine_tuning_train_accs, fine_tuning_val_losses, fine_tuning_val_accs =  training_loop(vgg_model_transfer, optimizer_fine_tuning, loss_fn_fine_tuning, train_dataloader, val_dataloader, num_epochs=num_epochs, print_every=10)
# Out:
# Starting training
# 	Batch 10/55: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.193, 	Val. acc.: 0.985
# 	Batch 20/55: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.150, 	Val. acc.: 0.982
# 	Batch 30/55: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.172, 	Val. acc.: 0.979
# 	Batch 40/55: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.183, 	Val. acc.: 0.979
# 	Batch 50/55: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.181, 	Val. acc.: 0.979
# Epoch 1/10: Train loss: 0.000, Train acc.: 1.000, Val. loss: 0.224, Val. acc.: 0.979
# 	Batch 10/55: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.207, 	Val. acc.: 0.984
# 	Batch 20/55: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.259, 	Val. acc.: 0.984
# 	Batch 30/55: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.259, 	Val. acc.: 0.984
# 	Batch 40/55: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.261, 	Val. acc.: 0.984
# 	Batch 50/55: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.263, 	Val. acc.: 0.984
# Epoch 2/10: Train loss: 0.000, Train acc.: 1.000, Val. loss: 0.265, Val. acc.: 0.984
# 	Batch 10/55: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.267, 	Val. acc.: 0.984
# 	Batch 20/55: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.268, 	Val. acc.: 0.983
# 	Batch 30/55: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.269, 	Val. acc.: 0.982
# 	Batch 40/55: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.269, 	Val. acc.: 0.982
# 	Batch 50/55: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.269, 	Val. acc.: 0.983
# Epoch 3/10: Train loss: 0.000, Train acc.: 1.000, Val. loss: 0.268, Val. acc.: 0.984
# 	Batch 10/55: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.266, 	Val. acc.: 0.984
# 	Batch 20/55: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.264, 	Val. acc.: 0.984
# 	Batch 30/55: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.266, 	Val. acc.: 0.984
# 	Batch 40/55: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.268, 	Val. acc.: 0.984
# 	Batch 50/55: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.269, 	Val. acc.: 0.984
# Epoch 4/10: Train loss: 0.000, Train acc.: 1.000, Val. loss: 0.269, Val. acc.: 0.984
# 	Batch 10/55: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.268, 	Val. acc.: 0.984
# 	Batch 20/55: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.268, 	Val. acc.: 0.984
# 	Batch 30/55: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.268, 	Val. acc.: 0.984
# 	Batch 40/55: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.268, 	Val. acc.: 0.984
# 	Batch 50/55: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.268, 	Val. acc.: 0.984
# Epoch 5/10: Train loss: 0.000, Train acc.: 1.000, Val. loss: 0.268, Val. acc.: 0.984
# 	Batch 10/55: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.268, 	Val. acc.: 0.984
# 	Batch 20/55: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.268, 	Val. acc.: 0.984
# 	Batch 30/55: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.268, 	Val. acc.: 0.984
# 	Batch 40/55: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.268, 	Val. acc.: 0.984
# 	Batch 50/55: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.268, 	Val. acc.: 0.984
# Epoch 6/10: Train loss: 0.000, Train acc.: 1.000, Val. loss: 0.269, Val. acc.: 0.984
# 	Batch 10/55: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.269, 	Val. acc.: 0.984
# 	Batch 20/55: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.268, 	Val. acc.: 0.984
# 	Batch 30/55: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.269, 	Val. acc.: 0.984
# 	Batch 40/55: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.269, 	Val. acc.: 0.984
# 	Batch 50/55: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.270, 	Val. acc.: 0.984
# Epoch 7/10: Train loss: 0.000, Train acc.: 1.000, Val. loss: 0.271, Val. acc.: 0.984
# 	Batch 10/55: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.271, 	Val. acc.: 0.984
# 	Batch 20/55: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.271, 	Val. acc.: 0.984
# 	Batch 30/55: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.272, 	Val. acc.: 0.984
# 	Batch 40/55: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.272, 	Val. acc.: 0.984
# 	Batch 50/55: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.272, 	Val. acc.: 0.984
# Epoch 8/10: Train loss: 0.000, Train acc.: 1.000, Val. loss: 0.272, Val. acc.: 0.984
# 	Batch 10/55: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.272, 	Val. acc.: 0.984
# 	Batch 20/55: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.272, 	Val. acc.: 0.984
# 	Batch 30/55: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.273, 	Val. acc.: 0.984
# 	Batch 40/55: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.273, 	Val. acc.: 0.984
# 	Batch 50/55: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.273, 	Val. acc.: 0.983
# Epoch 9/10: Train loss: 0.000, Train acc.: 1.000, Val. loss: 0.273, Val. acc.: 0.983
# 	Batch 10/55: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.274, 	Val. acc.: 0.983
# 	Batch 20/55: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.274, 	Val. acc.: 0.983
# 	Batch 30/55: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.274, 	Val. acc.: 0.983
# 	Batch 40/55: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.274, 	Val. acc.: 0.983
# 	Batch 50/55: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.274, 	Val. acc.: 0.983
# Epoch 10/10: Train loss: 0.000, Train acc.: 1.000, Val. loss: 0.274, Val. acc.: 0.983

# %% [markdown]
# **(1 point)**
#
# How does the model perform, compared to the model trained with frozen layers? Create one plot with the training accuracy and another with the validation accuracy of the two scenarios.

# %%
# YOUR CODE HERE
fine_tuning_train_losses_window_average = window_average(fine_tuning_train_losses, train_dataloader)
fine_tuning_train_accs_window_average = window_average(fine_tuning_train_accs, train_dataloader)

fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(12,5))
x = np.arange(1,num_epochs+1)

ax1.plot(x, vgg_train_accs_window_average, label='vgg_transfer_model')
ax1.plot(x, fine_tuning_train_accs_window_average, label='vgg_fine_tuning_model')
ax1.set_title('Training accuracy (vgg_transfer_model vs. vgg_fine_tuning_model)')
ax1.set_xlabel('Epoch')
ax1.set_ylabel('Accuracy')
ax1.set_xticks(x)
ax1.legend()

ax2.plot(x, vgg_val_accs, label='vgg_transfer_model')
ax2.plot(x, fine_tuning_val_accs, label='vgg_fine_tuning_model')
ax2.set_title('Validation accurancy (vgg_transfer_model vs. vgg_fine_tuning_model)')
ax2.set_xlabel('Epoch')
ax2.set_ylabel('Accuracy')
ax2.set_xticks(x)
ax2.legend()

plt.show()

# %% [markdown]
# **(2 points)**
#
# Why is it a good idea to use a very small learning rate when doing fine tuning?

# %% [markdown]
# **Your answer:**
#
# 1. Fine-tuning means adjusting the pre-trained model's weights for a new dataset. Since the model already possesses valuable knowledge from its pre-training, we aim to make gradual adjustments to preserve its learned knowledge.
# 2. Using small learning rates enhances the fine-tuning process's robustness to variations in the target dataset.

# %% [markdown]
# Save the model to file.

# %%
# YOUR CODE HERE
torch.save({'model_state_dict': vgg_model_fine_tuning.state_dict(),
            'train_losses': fine_tuning_train_losses,
            'train_accs': fine_tuning_train_accs,
            'val_losses': fine_tuning_val_losses,
            'val_accs': fine_tuning_val_accs,
            }, "./vgg_model_fine_tuning.ckpt")

# %% [markdown]
# ### 4.3 Improving the top model (optional)

# %% [markdown]
# Improve the architecture for the layers you add on top of VGG16. Try different ideas! When you're happy with one architecture, copy it in the cell below and train it here.

# %%
# YOUR CODE HERE

# %% [markdown]
# **(1 point)**
#
# How does the model perform, compared to the model trained in step 4.2? Create one plot with the training accuracy and another with the validation accuracy of the two scenarios.

# %%
# YOUR CODE HERE

# %% [markdown]
# Save the model to a file.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## 5. Final training

# %% [markdown]
# Now we'll train the model that achieved the best performance so far using the entire dataset.
#
# **Note**: start the optimization with the weights you obtained training in the smaller subset, i.e. *not* from scratch.

# %% [markdown]
# First, create two new data loaders, one for training samples and one for validation samples. This time, they'll load data from the folders for the entire dataset.

# %%
# YOUR CODE HERE
train_dataset = DogsCatsData(train_path, transform3)
val_dataset = DogsCatsData(val_path, transform3)

whole_train_dataloader = DataLoader(train_dataset, batch_size=64, shuffle=True)
whole_val_dataloader = DataLoader(val_dataset, batch_size=64)

# %% [markdown]
# **(1 point)**
#
# Train your model using the full data. This optimization might take a long time.

# %%
# YOUR CODE HERE

loss_fn_final = nn.BCELoss()
optimizer_final = torch.optim.Adam(vgg_model_fine_tuning.parameters(), lr=1e-5)
num_epochs = 10

model_final, model_train_losses_final, model_train_accs_final, model_val_losses_final, model_val_accs_final =  training_loop(vgg_model_fine_tuning, optimizer_final, loss_fn_final, whole_train_dataloader, whole_val_dataloader, num_epochs=num_epochs, print_every=70)
# Out:
# Starting training
# 	Batch 70/360: 	Train loss: 0.212, 	Train acc.: 0.987, 	Val. loss: 0.194, 	Val. acc.: 0.988
# 	Batch 140/360: 	Train loss: 0.103, 	Train acc.: 0.988, 	Val. loss: 0.190, 	Val. acc.: 0.989
# 	Batch 210/360: 	Train loss: 0.109, 	Train acc.: 0.986, 	Val. loss: 0.190, 	Val. acc.: 0.988
# 	Batch 280/360: 	Train loss: 0.224, 	Train acc.: 0.987, 	Val. loss: 0.144, 	Val. acc.: 0.989
# 	Batch 350/360: 	Train loss: 0.057, 	Train acc.: 0.988, 	Val. loss: 0.142, 	Val. acc.: 0.990
# Epoch 1/10: Train loss: 0.138, Train acc.: 0.987, Val. loss: 0.142, Val. acc.: 0.989
# 	Batch 70/360: 	Train loss: 0.096, 	Train acc.: 0.990, 	Val. loss: 0.141, 	Val. acc.: 0.989
# 	Batch 140/360: 	Train loss: 0.083, 	Train acc.: 0.988, 	Val. loss: 0.141, 	Val. acc.: 0.989
# 	Batch 210/360: 	Train loss: 0.110, 	Train acc.: 0.988, 	Val. loss: 0.139, 	Val. acc.: 0.989
# 	Batch 280/360: 	Train loss: 0.140, 	Train acc.: 0.988, 	Val. loss: 0.139, 	Val. acc.: 0.989
# 	Batch 350/360: 	Train loss: 0.041, 	Train acc.: 0.990, 	Val. loss: 0.095, 	Val. acc.: 0.990
# Epoch 2/10: Train loss: 0.093, Train acc.: 0.989, Val. loss: 0.094, Val. acc.: 0.990
# 	Batch 70/360: 	Train loss: 0.030, 	Train acc.: 0.992, 	Val. loss: 0.093, 	Val. acc.: 0.990
# 	Batch 140/360: 	Train loss: 0.073, 	Train acc.: 0.991, 	Val. loss: 0.092, 	Val. acc.: 0.990
# 	Batch 210/360: 	Train loss: 0.086, 	Train acc.: 0.988, 	Val. loss: 0.088, 	Val. acc.: 0.990
# 	Batch 280/360: 	Train loss: 0.087, 	Train acc.: 0.989, 	Val. loss: 0.089, 	Val. acc.: 0.991
# 	Batch 350/360: 	Train loss: 0.081, 	Train acc.: 0.990, 	Val. loss: 0.088, 	Val. acc.: 0.991
# Epoch 3/10: Train loss: 0.069, Train acc.: 0.990, Val. loss: 0.088, Val. acc.: 0.991
# 	Batch 70/360: 	Train loss: 0.029, 	Train acc.: 0.993, 	Val. loss: 0.087, 	Val. acc.: 0.991
# 	Batch 140/360: 	Train loss: 0.045, 	Train acc.: 0.993, 	Val. loss: 0.085, 	Val. acc.: 0.991
# 	Batch 210/360: 	Train loss: 0.048, 	Train acc.: 0.990, 	Val. loss: 0.084, 	Val. acc.: 0.991
# 	Batch 280/360: 	Train loss: 0.058, 	Train acc.: 0.991, 	Val. loss: 0.042, 	Val. acc.: 0.991
# 	Batch 350/360: 	Train loss: 0.097, 	Train acc.: 0.990, 	Val. loss: 0.084, 	Val. acc.: 0.990
# Epoch 4/10: Train loss: 0.055, Train acc.: 0.992, Val. loss: 0.084, Val. acc.: 0.990
# 	Batch 70/360: 	Train loss: 0.041, 	Train acc.: 0.993, 	Val. loss: 0.041, 	Val. acc.: 0.991
# 	Batch 140/360: 	Train loss: 0.022, 	Train acc.: 0.993, 	Val. loss: 0.042, 	Val. acc.: 0.991
# 	Batch 210/360: 	Train loss: 0.028, 	Train acc.: 0.993, 	Val. loss: 0.039, 	Val. acc.: 0.990
# 	Batch 280/360: 	Train loss: 0.049, 	Train acc.: 0.991, 	Val. loss: 0.039, 	Val. acc.: 0.990
# 	Batch 350/360: 	Train loss: 0.091, 	Train acc.: 0.992, 	Val. loss: 0.039, 	Val. acc.: 0.991
# Epoch 5/10: Train loss: 0.045, Train acc.: 0.992, Val. loss: 0.039, Val. acc.: 0.991
# 	Batch 70/360: 	Train loss: 0.013, 	Train acc.: 0.995, 	Val. loss: 0.038, 	Val. acc.: 0.991
# 	Batch 140/360: 	Train loss: 0.018, 	Train acc.: 0.994, 	Val. loss: 0.037, 	Val. acc.: 0.991
# 	Batch 210/360: 	Train loss: 0.113, 	Train acc.: 0.992, 	Val. loss: 0.037, 	Val. acc.: 0.992
# 	Batch 280/360: 	Train loss: 0.019, 	Train acc.: 0.993, 	Val. loss: 0.037, 	Val. acc.: 0.991
# 	Batch 350/360: 	Train loss: 0.032, 	Train acc.: 0.991, 	Val. loss: 0.037, 	Val. acc.: 0.991
# Epoch 6/10: Train loss: 0.038, Train acc.: 0.993, Val. loss: 0.037, Val. acc.: 0.990
# 	Batch 70/360: 	Train loss: 0.063, 	Train acc.: 0.994, 	Val. loss: 0.036, 	Val. acc.: 0.991
# 	Batch 140/360: 	Train loss: 0.020, 	Train acc.: 0.993, 	Val. loss: 0.036, 	Val. acc.: 0.991
# 	Batch 210/360: 	Train loss: 0.015, 	Train acc.: 0.995, 	Val. loss: 0.036, 	Val. acc.: 0.991
# 	Batch 280/360: 	Train loss: 0.065, 	Train acc.: 0.995, 	Val. loss: 0.035, 	Val. acc.: 0.992
# 	Batch 350/360: 	Train loss: 0.018, 	Train acc.: 0.994, 	Val. loss: 0.034, 	Val. acc.: 0.991
# Epoch 7/10: Train loss: 0.035, Train acc.: 0.994, Val. loss: 0.034, Val. acc.: 0.992
# 	Batch 70/360: 	Train loss: 0.014, 	Train acc.: 0.995, 	Val. loss: 0.033, 	Val. acc.: 0.991
# 	Batch 140/360: 	Train loss: 0.040, 	Train acc.: 0.994, 	Val. loss: 0.033, 	Val. acc.: 0.992
# 	Batch 210/360: 	Train loss: 0.014, 	Train acc.: 0.996, 	Val. loss: 0.034, 	Val. acc.: 0.992
# 	Batch 280/360: 	Train loss: 0.037, 	Train acc.: 0.995, 	Val. loss: 0.032, 	Val. acc.: 0.992
# 	Batch 350/360: 	Train loss: 0.060, 	Train acc.: 0.994, 	Val. loss: 0.033, 	Val. acc.: 0.992
# Epoch 8/10: Train loss: 0.033, Train acc.: 0.995, Val. loss: 0.033, Val. acc.: 0.991
# 	Batch 70/360: 	Train loss: 0.013, 	Train acc.: 0.996, 	Val. loss: 0.033, 	Val. acc.: 0.992
# 	Batch 140/360: 	Train loss: 0.033, 	Train acc.: 0.996, 	Val. loss: 0.032, 	Val. acc.: 0.991
# 	Batch 210/360: 	Train loss: 0.017, 	Train acc.: 0.995, 	Val. loss: 0.033, 	Val. acc.: 0.992
# 	Batch 280/360: 	Train loss: 0.057, 	Train acc.: 0.996, 	Val. loss: 0.032, 	Val. acc.: 0.991
# 	Batch 350/360: 	Train loss: 0.037, 	Train acc.: 0.996, 	Val. loss: 0.032, 	Val. acc.: 0.991
# Epoch 9/10: Train loss: 0.031, Train acc.: 0.996, Val. loss: 0.032, Val. acc.: 0.992
# 	Batch 70/360: 	Train loss: 0.032, 	Train acc.: 0.996, 	Val. loss: 0.032, 	Val. acc.: 0.992
# 	Batch 140/360: 	Train loss: 0.055, 	Train acc.: 0.996, 	Val. loss: 0.031, 	Val. acc.: 0.992
# 	Batch 210/360: 	Train loss: 0.010, 	Train acc.: 0.998, 	Val. loss: 0.031, 	Val. acc.: 0.992
# 	Batch 280/360: 	Train loss: 0.035, 	Train acc.: 0.995, 	Val. loss: 0.032, 	Val. acc.: 0.991
# 	Batch 350/360: 	Train loss: 0.013, 	Train acc.: 0.997, 	Val. loss: 0.032, 	Val. acc.: 0.991
# Epoch 10/10: Train loss: 0.029, Train acc.: 0.996, Val. loss: 0.032, Val. acc.: 0.991

# %% [markdown]
# **(1 point)**
#
# How does the model perform now when trained on the entire dataset, compared to when only trained on the smaller subset of data? Create one plot with the training accuracy and another with the validation accuracy of the two scenarios.

# %%
# YOUR CODE HERE
final_train_losses_window_average = window_average(model_train_losses_final, whole_train_dataloader)
final_train_accs_window_average = window_average(model_train_accs_final, whole_train_dataloader)

fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(12,5))
x = np.arange(1,num_epochs+1)

ax1.plot(x, final_train_accs_window_average, label='vgg_fine_tuning_model (entire dataset) ')
ax1.plot(x, fine_tuning_train_accs_window_average, label='vgg_fine_tuning_model (small subset data)')
ax1.set_title('Training accuracy (small subset vs. entire dataset)')
ax1.set_xlabel('Epoch')
ax1.set_ylabel('Accuracy')
ax1.set_xticks(x)
ax1.legend()

ax2.plot(x, model_val_accs_final, label='vgg_fine_tuning_model (entire dataset)')
ax2.plot(x, fine_tuning_val_accs, label='vgg_fine_tuning_model (small subset data)')
ax2.set_title('Validation accurancy (small subset vs. entire dataset)')
ax2.set_xlabel('Epoch')
ax2.set_ylabel('Accuracy')
ax2.set_xticks(x)
ax2.legend()

plt.show()

# %% [markdown]
# **(2 points)**
#
# What can you conclude from these plots? Did you expect what you observe in the plots, explain!

# %% [markdown]
# **Your answer:**
#
# 1. The "entire Dataset" vgg_fine_tuning_model achieved lower training accuracy compared to the "small subset" model. This is because "small subset" model is overfitting to the small traning dataset.
# 2. The "entire Dataset" vgg_fine_tuning_model achieved higher validation accuracy compared to the "small subset" model. This is because a larger dataset is less prone to overfitting because it has a richer set of examples.
# 3. The "small subset" model showed more variance in performance than the "entire Dataset" vgg_fine_tuning_model.

# %% [markdown]
# Save the model to a file.

# %%
# YOUR CODE HERE
torch.save({'model_state_dict': model_final.state_dict(),
            'train_losses': model_train_losses_final,
            'train_accs': model_train_accs_final,
            'val_losses': model_val_losses_final,
            'val_accs': model_val_accs_final,
            }, "./model_final.ckpt")

# %% [markdown]
# ## 6. Evaluation on test set (optional)

# %% [markdown]
# Now we'll evaluate your final model, obtained in step 6, on the test set. As mentioned before, the samples in the test set are not labelled, so we can't compute any supervised performance metrics ourselves.
#
# As a bit of fun and to inspire some friendly competition you may instead submit it to Kaggle for evaluation.
#
# Compute the predictions for all samples in the test set according to your best model, and save it in a .csv file with the format expected by the competition.
#
# For the test data we need a slightly different dataset class, due to the lack of labels in the data.
# A more proper way to implement it would be to make a common class which handles both the train and test settings.
# Here, we'll just copy the train dataset class and make some modifications to ignore the labels.
#
# Hints:
# - There is a `sampleSubmission.csv` file included in the zip data. Take a look at it to better understand what is the expected format here.
# - If you don't know how to create and write to files with Python, it's a well-behaved Google search.

# %%
from pathlib import Path
from PIL import Image
from time import time

class TestData(Dataset):
    
    def __init__(self, root: Path, transform):
        root = Path(root)
        if not (root.exists() and root.is_dir()):
            raise ValueError(f"Data root '{root}' is invalid")
            
        self.root = root
        self.transform = transform
        self._samples = self._collect_samples()
            
    def __getitem__(self, index):
        path = self._samples[index]
        num_id = int(path.stem)
        img = Image.open(path)
        if self.transform is not None:
            img = self.transform(img) 
        return img, num_id
    
    def __len__(self):
        return len(self._samples)
    
    def _collect_samples(self):
        test_paths = self._collect_imgs_sub_dir(self.root)
        return sorted(list(test_paths), key=lambda path: int(path.stem))
     
    @staticmethod
    def _collect_imgs_sub_dir(sub_dir: Path):
        if not sub_dir.exists():
            raise ValueError(f"Data root '{self.root}' must contain sub dir '{sub_dir.name}'")
        return sub_dir.glob("*.jpg")
    
    def get_sample_by_id(self, id_):
        id_index = self._samples.index(id_)
        return self[id_index]

# YOUR CODE HERE
# Define the CSV file path
csv_file = 'prediction_submission6.csv'

test_path = "./test"
test_dataset = TestData(test_path, transform3)
test_dataloader = DataLoader(test_dataset, batch_size=64)


all_predictions = []

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model_final.to(device)

model_final.eval()

with torch.no_grad():
    for batch_index, (x, y) in enumerate(test_dataloader, 1):
        inputs, labels = x.to(device), y.to(device)
        z = model_final.forward(inputs)
        # hard_preds = output_to_label(z)
        all_predictions.append(z)

output_list = [item for tensor in all_predictions for item in tensor.tolist()]

data = [{"id": i + 1, "label": output_list[i]} for i in range(len(output_list))]

# Create a DataFrame from the data
df = pd.DataFrame(data)

# Write the DataFrame to the CSV file
df.to_csv(csv_file, index=False)

print(f'Prediction has been written to {csv_file}.')
# Out:
# Prediction has been written to prediction_submission.csv.

# %% [markdown]
# Now that you created your submission file, submit it to Kaggle for evaluation. The [old competition](https://www.kaggle.com/c/dogs-vs-cats) does not allow submissions any more, but you can submit your file to the [new one](https://www.kaggle.com/c/dogs-vs-cats-redux-kernels-edition) via the "Late submission" button (they use the same data). The Kaggle CLI can be used as well. Kaggle evaluates your submission according to your log-loss score. Which score did you obtain?

# %% [markdown]
# **Your answer:** (fill in here)

# %% [markdown]
# What was the username you used for this submission?

# %% [markdown]
# **Your answer:** (fill in here)
